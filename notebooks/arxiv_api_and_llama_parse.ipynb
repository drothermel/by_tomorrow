# %%
# Imports for axiv api
import feedparser
from datetime import datetime, timedelta, timezone

# %%
# Imports for Llama parse
from dotenv import load_dotenv
load_dotenv()
from llama_parse import LlamaParse
import requests
# Out:
# True

# %%
# Import for both
import dr_util.file_utils as fu
import os
import time

# %%
# Path constants, make into config
RAW_PDF_DIR = "/Users/daniellerothermel/drotherm/data/raw_pdfs/"
PARSED_PDF_DIR = "/Users/daniellerothermel/drotherm/data/parsed_pdfs/"
METADATA_DIR = "/Users/daniellerothermel/drotherm/data/pdf_metadata/"

# %% [markdown]
# ## Parsing Metrics

# %%
# count every 10 mins
total_parsed = [14, 25, 36, 45, 45, 53, 61, 70, 79, 79, 85, 88, 94, 95, 95, 107, 118, 125, 128, 133, 133, 141, 151, 160, 171, 183, 196, 209, 220, 226, 226, 240, 253, 262, 268, 275, 286, 293, 306, 312, 325]
start = total_parsed[0]
diffs = []
for tp in total_parsed[1:]:
    diffs.append(tp - start)
    start = tp
total = sum(diffs)
count = len(diffs)
print(f">> Llama Parse Processed {total*6/count:0.2f} papers/hr or {total/(count*10):0.2f} papers/min on average over a few hours")
# Out:
# >> Llama Parse Processed 46.65 papers/hr or 0.78 papers/min on average over a few hours

# %% [markdown]
# ## Util Fxns

# %%
def make_arxiv_api_query_by_ids(id_list):
    assert len(id_list) > 0
    
    url_base = "https://export.arxiv.org/api/query"
    query_type = "id_list"
    id_list_str = ",".join(id_list)
    start = 0
    max_results = len(id_list)
    return f"{url_base}?{query_type}={id_list_str}&start={start}&max_results={max_results}"

# %%
def make_arxiv_api_query_by_author(author, max_results=100):
    url_base = "https://export.arxiv.org/api/query"
    query_type = "search_query"
    query_str = f'au:"{author.replace(' ', '%20')}"'
    start = 0
    sort_str = "sortBy=submittedDate&sortOrder=descending"
    return f"{url_base}?{query_type}={query_str}&start={start}&max_results={max_results}&{sort_str}"

# %%
def paper_feed_to_structured_info(p_feed):
    if 'entries' in p_feed:
        pd = p_feed['entries'][0]
    else:
        pd = p_feed
    pdf_link = None
    for ldict in pd['links']:
        if ldict.get('title', '') == 'pdf':
            pdf_link = ldict['href']
    return {
        'title': pd['title'],
        'abstract': pd['summary'],
        'published': pd['published'],
        'updated': pd['updated'],
        'authors': [a['name'] for a in pd['authors']],
        'pdf_link': pdf_link,
    }

# %%
def filter_dicts_by_years(dict_list, years, date_key):
    # Get the current date
    today = datetime.now(timezone.utc)
    
    # Calculate the threshold date (years ago from today)
    threshold_date = today - timedelta(days=years*365)  # Approximation for leap years
    
    # Filter the list of dicts
    filtered_dicts = [d for d in dict_list if datetime.strptime(d[date_key], '%Y-%m-%dT%H:%M:%SZ').replace(tzinfo=timezone.utc) >= threshold_date]
    
    return filtered_dicts

# %%
def download_pdf(url, save_path):
    """
    Downloads a PDF from the given URL and saves it to the specified location.
    
    Args:
    url (str): The URL of the PDF to download.
    save_path (str): The path (including filename) where the PDF will be saved.
    """
    try:
        # Send a GET request to the URL
        response = requests.get(url)
        
        # Check if the request was successful
        if response.status_code == 200:
            # Write the content to a file in binary mode
            with open(save_path, 'wb') as pdf_file:
                pdf_file.write(response.content)
            print(f"PDF downloaded and saved to {save_path}")
        else:
            print(f"Failed to download PDF. Status code: {response.status_code}")
    except Exception as e:
        print(f"An error occurred: {e}")

# %% [markdown]
# ## Combine Util Fxns

# %%
def query_dump_download_by_author(author, max_results):
    print(f">> Getting papers from author: {author}")
    # First get all the recent papers by this author, ordered by date
    query = make_arxiv_api_query_by_author(author, max_results=max_results)
    parsed_feed = feedparser.parse(query)

    print(f">> Total number papers: {len(parsed_feed['entries'])}")
    structured_responses = [paper_feed_to_structured_info(pent) for pent in parsed_feed['entries']]

    pdfs_metadata = {}

    # Save all structured responses individually by pdf_url info
    # then download the pdf to the right location
    print(">> Dumping Metadata and Downloading PDFs")
    for sr  in structured_responses:
        pdf_url = sr['pdf_link']
        pdf_name = pdf_url.split('/')[-1]
        pdfs_metadata[pdf_name] = {**sr}

        # Dump metadata
        metadata_path = f'{METADATA_DIR}{pdf_name}.json'
        fu.dump_file(sr, metadata_path, verbose=False)
        pdfs_metadata[pdf_name]['metadata_path'] = metadata_path

        # Download the raw PDF
        raw_path = f'{RAW_PDF_DIR}{pdf_name}.pdf'
        if not os.path.exists(raw_path):
            download_pdf(pdf_url.replace("arxiv.org", "export.arxiv.org"), raw_path)
            time.sleep(4)
        pdfs_metadata[pdf_name]['raw_path'] = raw_path

        print(f" - {pdf_name}: {sr['title']}\n")

    query_metadata = {
        'author': author,
        'query': query,
        'max_results': max_results,
        'num_results': len(structured_responses),
        'pdfs_metadata': pdfs_metadata,
    }
    fu.dump_file(query_metadata, f'{METADATA_DIR}{author.replace(" ", "_")}_query_metadata.json', verbose=True)

# %%
# Requires the following two lines to run first
# import nest_asyncio
# nest_asyncio.apply()
def load_author_select_recent_llama_parse(author, num_years=2, max_parse=1):
    # First load the author metadata
    author_metadata_path = f'{METADATA_DIR}{author.replace(" ", "_")}_query_metadata.json'
    amd = fu.load_file(author_metadata_path)
    all_papers = [{**v, 'name': k} for k, v in amd['pdfs_metadata'].items()]

    # Then get the papers from the last N years
    recent_papers = filter_dicts_by_years(all_papers, num_years, date_key="published")
    print(f">> {author} has {len(recent_papers)} / {len(all_papers)} in the last {num_years} years")

    parser = LlamaParse(result_type="markdown")

    # Then for each paper use llama parse to process and dump the paper
    num_parsed = 0
    for rp in recent_papers:
        if num_parsed >= max_parse:
            print(f">> Reached parse: {num_parsed}, break")
            break
        pdf_name = rp['name']
        full_pdf_path = rp['raw_path']
        parsed_pdf_path = f'{PARSED_PDF_DIR}{pdf_name}.pkl'
        #print(f">> Parsed pdf to write: {parsed_pdf_path}")
        if not os.path.exists(parsed_pdf_path):
            print(f">> Begin parsing number: {num_parsed}")
            rp_docs = parser.load_data(full_pdf_path)
            fu.dump_file(rp_docs, parsed_pdf_path, verbose=True)
            print(f" - {len(rp_docs)} blocks for paper: {rp['title']}")
            num_parsed += 1
            time.sleep(3)

# %% [markdown]
# ## Test Util Fxns

# %%
title = "Gradient Matching for Domain Generalization"
first_author = "Yuge Shi"
last_author = "Gabriel Synnaeve"
arxiv_id = "2104.09937"
pdf_url = "https://arxiv.org/pdf/2104.09937"

# %% [markdown]
# ### Query Single Paper, Extract Data

# %%
q1 = make_arxiv_api_query_by_ids([arxiv_id])
q1

# %%
paper_feed_to_structured_info(feedparser.parse(q1))

# %% [markdown]
# ### Query Papers by Author

# %%
q2 = make_arxiv_api_query_by_author(last_author, max_results=1000)
q2

# %%
p2s = feedparser.parse(q2)
len(p2s['entries'])

# %%
parsed_p2s = [paper_feed_to_structured_info(pent) for pent in p2s['entries']]

# %%
parsed_p2s[-1]

# %%
within_2_yrs = filter_dicts_by_years(parsed_p2s, 2, date_key="published")

# %%
within_2_yrs[-1]

# %% [markdown]
# ### Download PDF and Parse with LlamaParse

# %%
pdf_name = pdf_url.split('/')[-1]
full_pdf_path = f'{raw_pdf_path}{pdf_name}.pdf'
download_pdf(pdf_url, full_pdf_path)

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
parser = LlamaParse(result_type="markdown")

# %%
docs = parser.load_data(full_pdf_path)

# %%
print(docs[1].text[:1000])

# %%
full_parsed_pdf_path = f'{parsed_pdf_path}{pdf_name}.pkl'
fu.dump_file(docs, full_parsed_pdf_path)

# %%
docs_load = fu.load_file(full_parsed_pdf_path)

# %%
print(docs_load[1].text[:1000])

# %% [markdown]
# ## Query Arxiv API and Download PDF

# %% [markdown]
# #### He He: 67 (13, 27, 36, 40, 44)

# %%
query_dump_download_by_author('He He', 70)
# Out:
# >> Getting papers from author: He He
# >> Total number papers: 67
# >> Dumping Metadata and Downloading PDFs
#  - 2409.12822v2: Language Models Learn to Mislead Humans via RLHF
#
#  - 2407.04549v1: Spontaneous Reward Hacking in Iterative Self-Refinement
#
#  - 2406.12158v1: LLMs Are Prone to Fallacies in Causal Inference
#
#  - 2404.19733v3: Iterative Reasoning Preference Optimization
#
#  - 2404.16019v1: The PRISM Alignment Project: What Participatory, Representative and
#   Individualised Human Feedback Reveals About the Subjective and Multicultural
#   Alignment of Large Language Models
#
#  - 2404.09932v2: Foundational Challenges in Assuring Alignment and Safety of Large
#   Language Models
#
#  - 2404.00246v1: Your Co-Workers Matter: Evaluating Collaborative Capabilities of
#   Language Models in Blocks World
#
#  - 2402.12530v1: Parallel Structures in Pre-training Data Yield In-Context Learning
#
#  - 2401.13986v1: Towards Consistent Natural-Language Explanations via
#   Explanation-Consistency Finetuning
#
#  - 2401.06176v1: GOODAT: Towards Test-time Graph Out-of-Distribution Detection
#
#  - 2311.17154v1: Pragmatic Radiology Report Generation
#
#  - 2311.09480v2: Show Your Work with Confidence: Confidence Bands for Tuning Curves
#
#  - 2310.18168v5: Personas as a Way to Model Truthfulness in Language Models
#
#  - 2309.05196v3: Does Writing with Language Models Reduce Content Diversity?
#
#  - 2309.01079v2: Three-dimensional angular deviation and diffraction efficiency of a
#   grating in Littrow-configuration ECDL
#
#  - 2308.06246v1: ARGUS: Visualization of AI-Assisted Task Guidance in AR
#
#  - 2307.14117v2: Leveraging Implicit Feedback from Deployment Data in Dialogue
#
#  - 2307.08678v1: Do Models Explain Themselves? Counterfactual Simulatability of Natural
#   Language Explanations
#
#  - 2305.19998v1: Efficient Shapley Values Estimation by Amortization for Text
#   Classification
#
#  - 2305.15269v3: Testing the General Deductive Reasoning Capacity of Large Language
#   Models Using OOD Examples
#
#  - 2305.13299v1: Measuring Inductive Biases of In-Context Learning with Underspecified
#   Demonstrations
#
#  - 2303.17006v1: How do decoding algorithms distribute information in dialogue responses?
#
#  - 2303.04562v3: Extrapolative Controlled Sequence Generation via Iterative Refinement
#
#  - 2211.08714v3: Reward Gaming in Conditional Text Generation
#
#  - 2210.14011v1: Are All Spurious Features in Natural Language Alike? An Analysis through
#   a Causal Lens
#
#  - 2210.13669v1: Help me write a poem: Instruction Tuning as a Vehicle for Collaborative
#   Poetry Writing
#
#  - 2210.04782v2: Robustification of Multilingual Language Models to Real-world Noise in
#   Crosslingual Zero-shot Settings with Robust Contrastive Pretraining
#
#  - 2210.01302v3: Nuisances via Negativa: Adjusting for Spurious Correlations via Data
#   Augmentation
#
#  - 2210.01240v4: Language Models Are Greedy Reasoners: A Systematic Formal Analysis of
#   Chain-of-Thought
#
#  - 2209.07661v3: On the Relation between Sensitivity and Accuracy in In-context Learning
#
#  - 2204.11117v2: Exploring the Role of Task Transferability in Large-Scale Multi-Task
#   Learning
#
#  - 2112.13709v2: Rethinking the Data Annotation Process for Multi-view 3D Pose Estimation
#   with Active Learning and Self-Training
#
#  - 2112.08670v2: Amortized Noisy Channel Neural Machine Translation
#
#  - 2112.08608v2: QuALITY: Question Answering with Long Input Texts, Yes!
#
#  - 2111.04193v2: Machine-in-the-Loop Rewriting for Creative Image Captioning
#
#  - 2110.07814v2: Meta-learning via Language Model In-context Tuning
#
#  - 2109.06827v2: Types of Out-of-Distribution Texts and How to Detect Them
#
#  - 2108.13684v3: Faithful or Extractive? On Mitigating the Faithfulness-Abstractiveness
#   Trade-off in Abstractive Summarization
#
#  - 2107.00753v3: An Investigation of the (In)effectiveness of Counterfactually Augmented
#   Data
#
#  - 2102.06272v2: Unsupervised Extractive Summarization using Pointwise Mutual Information
#
#  - 2009.07839v2: Text Generation by Learning from Demonstrations
#
#  - 2007.06778v3: An Empirical Study on Robustness to Spurious Correlations using
#   Pre-trained Language Models
#
#  - 2005.03754v1: FEQA: A Question Answering Evaluation Framework for Faithfulness
#   Assessment in Abstractive Summarization
#
#  - 1912.01166v4: Different Set Domain Adaptation for Brain-Computer Interfaces: A Label
#   Alignment Approach
#
#  - 1909.13426v1: A Dynamic Strategy Coach for Effective Negotiation
#
#  - 1908.10763v2: Unlearn Dataset Bias in Natural Language Inference by Fitting the
#   Residual
#
#  - 1908.07323v2: Instance Scale Normalization for image understanding
#
#  - 1908.06180v3: Multi-View Broad Learning System for Primate Oculomotor Decision
#   Decoding
#
#  - 1907.04433v2: GluonCV and GluonNLP: Deep Learning in Computer Vision and Natural
#   Language Processing
#
#  - 1904.06828v1: Pun Generation with Surprise
#
#  - 1904.04792v2: Quizbowl: The Case for Incremental Question Answering
#
#  - 1808.09637v1: Decoupling Strategy and Generation in Negotiation Dialogues
#
#  - 1808.07036v3: QuAC : Question Answering in Context
#
#  - 1808.05464v2: Transfer Learning for Brain-Computer Interfaces: A Euclidean Space Data
#   Alignment Approach
#
#  - 1808.05853v1: Transfer Learning Enhanced Common Spatial Pattern Filtering for Brain
#   Computer Interfaces (BCIs): Overview and a New Approach
#
#  - 1808.06533v1: Spatial Filtering for Brain Computer Interfaces: A Comparison between
#   the Common Spatial Pattern and Its Variant
#
#  - 1805.04623v1: Sharp Nearby, Fuzzy Far Away: How Neural Language Models Use Context
#
#  - 1804.06437v1: Delete, Retrieve, Generate: A Simple Approach to Sentiment and Style
#   Transfer
#
#  - 1705.07966v1: Using Sloppy Models for Constrained Emittance Minimization at the
#   Cornell Electron Storage Ring (CESR)
#
#  - 1704.07130v1: Learning Symmetric Collaborative Dialogue Agents with Dynamic Knowledge
#   Graph Embeddings
#
# PDF downloaded and saved to /Users/daniellerothermel/drotherm/data/raw_pdfs/1611.10176v1.pdf
#  - 1611.10176v1: Effective Quantization Methods for Recurrent Neural Networks
#
# PDF downloaded and saved to /Users/daniellerothermel/drotherm/data/raw_pdfs/1609.05559v1.pdf
#  - 1609.05559v1: Opponent Modeling in Deep Reinforcement Learning
#
# PDF downloaded and saved to /Users/daniellerothermel/drotherm/data/raw_pdfs/1602.02181v1.pdf
#  - 1602.02181v1: Active Information Acquisition
#
# PDF downloaded and saved to /Users/daniellerothermel/drotherm/data/raw_pdfs/1503.05615v2.pdf
#  - 1503.05615v2: Learning to Search for Dependencies
#
# PDF downloaded and saved to /Users/daniellerothermel/drotherm/data/raw_pdfs/1406.1837v5.pdf
#  - 1406.1837v5: A Credit Assignment Compiler for Joint Prediction
#
# PDF downloaded and saved to /Users/daniellerothermel/drotherm/data/raw_pdfs/1212.6132v1.pdf
#  - 1212.6132v1: Epitaxial strain induced magnetic transitions and phonon instabilities
#   of the tetragonal SrRuO3
#
# PDF downloaded and saved to /Users/daniellerothermel/drotherm/data/raw_pdfs/0008001v1.pdf
#  - 0008001v1: SU(2) gluon propagator on a coarse anisotropic lattice

# %% [markdown]
# #### Rajesh Ranganath: 70 (8, 18, 28, 35, 40)

# %%
query_dump_download_by_author('Rajesh Ranganath', 80)
# Out:
# >> Getting papers from author: Rajesh Ranganath
# >> Total number papers: 70
# >> Dumping Metadata and Downloading PDFs
#  - 2407.07998v1: What's the score? Automated Denoising Score Matching for Nonlinear
#   Diffusions
#
#  - 2406.13660v1: Towards Minimal Targeted Updates of Language Models with Targeted
#   Negative Training
#
#  - 2406.04318v1: Adaptive Sampling of k-Space in Magnetic Resonance for Rapid Pathology
#   Prediction
#
#  - 2405.19534v3: Preference Learning Algorithms Do Not Learn Preference Rankings
#
#  - 2403.00025v1: On the Challenges and Opportunities in Generative AI
#
#  - 2401.08777v1: Robust Anomaly Detection for Particle Physics Using Multi-Background
#   Representation Learning
#
#  - 2312.01210v4: When accurate prediction models yield harmful self-fulfilling prophecies
#
#  - 2311.12781v1: Quantifying Impairment and Disease Severity Using AI Models Trained on
#   Healthy Subjects
#
#  - 2310.03725v3: Stochastic interpolants with data-dependent couplings
#
#  - 2308.12553v1: Don't blame Dataset Shift! Shortcut Learning due to Gradients and Cross
#   Entropy
#
#  - 2308.04431v1: When More is Less: Incorporating Additional Datasets Can Hurt
#   Performance By Introducing Spurious Correlations
#
#  - 2306.01196v1: An Effective Meaningful Way to Evaluate Survival Models
#
#  - 2303.12888v2: A dynamic risk score for early prediction of cardiogenic shock using
#   machine learning
#
#  - 2302.12893v1: Don't be fooled: label leakage in explanation methods and the importance
#   of their quantitative evaluation
#
#  - 2302.09344v2: Beyond Distribution Shift: Spurious Features Through the Lens of
#   Training Dynamics
#
#  - 2302.07261v2: Where to Diffuse, How to Diffuse, and How to Get Back: Automated
#   Learning for Multivariate Diffusions
#
#  - 2302.04132v1: Robustness to Spurious Correlations Improves Semantic
#   Out-of-Distribution Detection
#
#  - 2301.11962v2: On the Feasibility of Machine Learning Augmented Magnetic Resonance for
#   Point-of-Care Identification of Disease
#
#  - 2210.01302v3: Nuisances via Negativa: Adjusting for Spurious Correlations via Data
#   Augmentation
#
#  - 2209.07397v2: From algorithms to action: improving patient care requires causality
#
#  - 2208.10759v1: Survival Mixture Density Networks
#
#  - 2208.08579v2: DIET: Conditional independence testing with marginal dependence measures
#   of residual information
#
#  - 2206.11925v2: Set Norm and Equivariant Skip Connections: Putting the Deep in Deep Sets
#
#  - 2205.02900v2: New-Onset Diabetes Assessment Using Artificial Intelligence-Enhanced
#   Electrocardiography
#
#  - 2204.13975v2: Conditional average treatment effect estimation with marginally
#   constrained models
#
#  - 2112.00950v1: Quantile Filtered Imitation Learning
#
#  - 2112.00881v2: Learning Invariant Representations with Missing Data
#
#  - 2111.08175v2: Inverse-Weighted Survival Games
#
#  - 2107.07436v3: FastSHAP: Real-Time Shapley Value Estimation
#
#  - 2107.06908v2: Understanding Failures in Out-of-Distribution Detection with Deep
#   Generative Models
#
#  - 2107.00520v5: Out-of-distribution Generalization in the Presence of Nuisance-Induced
#   Spurious Correlations
#
#  - 2106.08909v3: Offline RL Without Off-Policy Evaluation
#
#  - 2103.01890v1: Have We Learned to Explain?: How Interpretability Methods Can Learn to
#   Encode Predictions in their Interpretations
#
#  - 2102.08533v1: Causal Estimation with Functional Confounders
#
#  - 2101.05346v1: X-CAL: Explicit Calibration for Survival Analysis
#
#  - 2009.11087v1: Probabilistic Machine Learning for Healthcare
#
#  - 2007.15835v1: Deep Direct Likelihood Knockoffs
#
#  - 2006.15368v4: Offline Contextual Bandits with Overparameterized Models
#
#  - 2001.03115v2: The Counterfactual $χ$-GAN
#
#  - 1910.14265v2: Energy-Inspired Models: Learning with Sampler-Induced Distributions
#
#  - 1908.00882v5: Population Predictive Checks
#
#  - 1907.03451v2: General Control Functions for Causal Effect Estimation from Instrumental
#   Variables
#
#  - 1907.01463v1: Reproducibility in Machine Learning for Health
#
#  - 1905.05163v2: Adversarial Examples for Electrocardiograms
#
#  - 1904.05342v3: ClinicalBERT: Modeling Clinical Notes and Predicting Hospital
#   Readmission
#
#  - 1904.04478v4: Kernelized Complete Conditional Stein Discrepancy
#
#  - 1903.10556v1: The Random Conditional Distribution for Higher-Order Probabilistic
#   Inference
#
#  - 1903.03448v4: Support and Invertibility in Domain-Invariant Representations
#
#  - 1903.02984v3: The Variational Predictive Natural Gradient
#
#  - 1901.05437v1: Soft Constraints for Inference with Declarative Knowledge
#
#  - 1806.00388v4: A Review of Challenges and Opportunities in Machine Learning for Health
#
#  - 1805.08273v3: Multiple Causal Inference with Latent Confounding
#
#  - 1805.01500v2: Noisin: Unbiased Regularization for Recurrent Neural Networks
#
#  - 1705.11140v2: Variational Sequential Monte Carlo
#
#  - 1705.08931v1: Proximity Variational Inference
#
#  - 1702.08896v3: Hierarchical Implicit Models and Likelihood-Free Variational Inference
#
#  - 1611.03414v2: Identifying potentially induced seismicity and assessing statistical
#   significance in Oklahoma and California
#
#  - 1611.00328v4: Variational Inference via $χ$-Upper Bound Minimization
#
#  - 1610.09033v3: Operator Variational Inference
#
#  - 1608.02158v2: Deep Survival Analysis
#
#  - 1603.00788v1: Automatic Differentiation Variational Inference
#
#  - 1511.06499v4: The Variational Gaussian Process
#
#  - 1511.02386v2: Hierarchical Variational Models
#
#  - 1509.04640v1: Dynamic Poisson Factorization
#
#  - 1507.05253v2: The Population Posterior and Bayesian Inference on Streams
#
#  - 1507.00720v3: Correlated Random Measures
#
#  - 1506.03431v2: Automatic Variational Inference in Stan
#
#  - 1411.2581v1: Deep Exponential Families
#
#  - 1411.1810v4: Variational Tempering
#
#  - 1401.0118v1: Black Box Variational Inference

# %% [markdown]
# #### Eunsol Choi: 64 (13, 32, 39, 50, 54)

# %%
query_dump_download_by_author('Eunsol Choi', 70)
# Out:
# >> Getting papers from author: Eunsol Choi
# >> Total number papers: 64
# >> Dumping Metadata and Downloading PDFs
#  - 2409.18110v1: Open-World Evaluation for Retrieving Diverse Perspectives
#
#  - 2408.06303v1: Long-Form Answers to Visual Questions from Blind and Low Vision People
#
#  - 2407.06249v1: CodeUpdateArena: Benchmarking Knowledge Editing on API Updates
#
#  - 2406.17761v2: CaLMQA: Exploring culturally specific long-form question answering
#   across 23 languages
#
#  - 2406.17692v1: From Distributional to Overton Pluralism: Investigating Large Language
#   Model Alignment
#
#  - 2406.14670v1: Exploring Design Choices for Building Language-Specific LLMs
#
#  - 2405.19597v1: SVFT: Parameter-Efficient Fine-Tuning with Singular Vectors
#
#  - 2404.12447v3: AmbigDocs: Reasoning across Documents on Different Entities under the
#   Same Name
#
#  - 2403.03866v1: KIWI: A Dataset of Knowledge-Intensive Writing Instructions for
#   Answering Research Questions
#
#  - 2402.01591v2: BAT: Learning to Reason about Spatial Sounds with Large Language Models
#
#  - 2311.09579v2: Crafting In-context Examples according to LMs' Parametric Knowledge
#
#  - 2311.09469v1: Clarify When Necessary: Resolving Ambiguity Through Interaction with LMs
#
#  - 2310.12150v1: Understanding Retrieval Augmentation for Long-Form Question Answering
#
#  - 2310.04408v1: RECOMP: Improving Retrieval-Augmented LMs with Compression and Selective
#   Augmentation
#
#  - 2308.07407v1: Development and Evaluation of Three Chatbots for Postpartum Mood and
#   Anxiety Disorders
#
#  - 2306.09306v2: Propagating Knowledge Updates to LMs Through Distillation
#
#  - 2306.08667v1: When to Use Efficient Self Attention? Profiling Text, Speech and Image
#   Transformer Variants
#
#  - 2305.19271v1: Concise Answers to Complex Questions: Summarization of Long-form Answers
#
#  - 2305.18201v1: A Critical Evaluation of Evaluations for Long-form Question Answering
#
#  - 2305.15405v2: Textless Low-Resource Speech-to-Speech Translation With Unit Language
#   Models
#
#  - 2305.14824v3: Mitigating Temporal Misalignment by Discarding Outdated Facts
#
#  - 2305.12473v2: Continually Improving Extractive QA via Human Feedback
#
#  - 2305.11859v2: Complex Claim Verification with Evidence Retrieved in the Wild
#
#  - 2305.01651v1: Can LMs Learn New Entities from Descriptions? Challenges in Propagating
#   Injected Knowledge
#
#  - 2303.00242v1: DIFFQG: Generating Questions to Summarize Factual Changes
#
#  - 2301.09044v2: Learning to Reject with a Fixed Predictor: Application to
#   Decontextualization
#
#  - 2212.11455v1: Understanding Postpartum Parents' Experiences via Two Digital Platforms
#
#  - 2212.01393v2: Continual Learning for On-Device Speech Recognition using Disentangled
#   Conformers
#
#  - 2211.16496v1: TyDiP: A Dataset for Politeness Classification in Nine Typologically
#   Diverse Languages
#
#  - 2211.15649v1: Beyond Counting Datasets: A Survey of Multilingual Dataset Construction
#   and Necessary Resources
#
#  - 2211.00768v4: Why is Winoground Hard? Investigating Failures in Visuolinguistic
#   Compositionality
#
#  - 2210.13701v1: Rich Knowledge Sources Bring Complex Knowledge Conflicts: Recalibrating
#   Models to Reflect Conflicting Evidence
#
#  - 2207.00758v1: MIA 2022 Shared Task: Evaluating Cross-lingual Open-Retrieval Question
#   Answering for 16 Diverse Languages
#
#  - 2206.14729v1: longhorns at DADC 2022: How many linguists does it take to fool a
#   Question Answering model? A systematic approach to adversarial attacks
#
#  - 2205.09278v1: Modeling Exemplification in Long-form Question Answering via Retrieval
#
#  - 2205.06938v3: Generating Literal and Implied Subquestions to Fact-check Complex Claims
#
#  - 2205.02832v1: Entity Cloze By Date: What LMs Know About Unseen Entities
#
#  - 2203.11048v1: How Do We Answer Complex Questions: Discourse Structure of Long-form
#   Answers
#
#  - 2203.10079v1: Simulating Bandit Learning from User Feedback for Extractive Question
#   Answering
#
#  - 2109.06157v1: SituatedQA: Incorporating Extra-Linguistic Contexts into QA
#
#  - 2109.04408v2: Learning with Different Amounts of Annotation: From Zero to Many Labels
#
#  - 2109.01653v1: CREAK: A Dataset for Commonsense Reasoning over Entity Knowledge
#
#  - 2106.01494v1: Knowing More About Questions Can Help: Improving Calibration in Question
#   Answering
#
#  - 2104.08790v4: Misinfo Reaction Frames: Reasoning about Readers' Reactions to News
#   Headlines
#
#  - 2104.08731v2: Can NLI Models Verify QA Systems' Predictions?
#
#  - 2102.06859v1: Capturing Label Distribution: A Case Study in NLI
#
#  - 2102.05169v1: Decontextualization: Making Sentences Stand-Alone
#
#  - 2101.00133v2: NeurIPS 2020 EfficientQA Competition: Systems, Analyses and Lessons
#   Learned
#
#  - 2010.11915v2: Challenges in Information-Seeking QA: Unanswerable Questions and
#   Paragraph Retrieval
#
#  - 2010.11856v3: XOR QA: Cross-lingual Open-Retrieval Question Answering
#
#  - 2009.06354v1: QED: A Framework and Dataset for Explanations in Question Answering
#
#  - 2004.07202v2: Entities as Experts: Sparse Memory Access with Entity Supervision
#
#  - 2003.05002v1: TyDi QA: A Benchmark for Information-Seeking Question Answering in
#   Typologically Diverse Languages
#
#  - 1910.09753v2: MRQA 2019 Shared Task: Evaluating Generalization in Reading
#   Comprehension
#
#  - 1904.08950v1: No Permanent Friends or Enemies: Tracking Relationships between Nations
#   from News
#
#  - 1810.08854v2: pair2vec: Compositional Word-Pair Embeddings for Cross-Sentence
#   Inference
#
#  - 1810.06683v3: FlowQA: Grasping Flow in History for Conversational Machine
#   Comprehension
#
#  - 1808.09653v1: Neural Metaphor Detection in Context
#
#  - 1808.07036v3: QuAC : Question Answering in Context
#
#  - 1807.04905v1: Ultra-Fine Entity Typing
#
#  - 1706.04115v1: Zero-Shot Relation Extraction via Reading Comprehension
#
#  - 1705.03551v2: TriviaQA: A Large Scale Distantly Supervised Challenge Dataset for
#   Reading Comprehension
#
#  - 1611.01839v2: Hierarchical Question Answering for Long Documents
#
#  - 1206.1066v1: Hedge detection as a lens on framing in the GMO debates: A position
#   paper

# %% [markdown]
# #### Mengye Ren: 47 (10, 12, 14, 26, 36)

# %%
query_dump_download_by_author('Mengye Ren', 50)
# Out:
# >> Getting papers from author: Mengye Ren
# >> Total number papers: 47
# >> Dumping Metadata and Downloading PDFs
#  - 2408.11208v1: PooDLe: Pooled and dense self-supervised learning from naturalistic
#   videos
#
#  - 2408.02226v2: ProCreate, Don't Reproduce! Propulsive Energy Diffusion for Creative
#   Generation
#
#  - 2404.19132v2: Integrating Present and Past in Unsupervised Continual Learning
#
#  - 2403.15362v1: CoLLEGe: Concept Embedding Generation for Large Language Models
#
#  - 2403.09613v1: Reawakening knowledge: Anticipatory recovery from catastrophic
#   interference via structured training
#
#  - 2402.00300v2: Self-supervised learning of video representations from a child's
#   perspective
#
#  - 2312.12736v2: Learning and Forgetting Unsafe Examples in Large Language Models
#
#  - 2312.05269v2: LifelongMemory: Leveraging LLMs for Answering Queries in Long-form
#   Egocentric Videos
#
#  - 2311.17218v1: BIM: Block-Wise Self-Supervised Learning with Masked Image Modeling
#
#  - 2311.02007v1: Towards Unsupervised Object Detection From LiDAR Point Clouds
#
#  - 2306.15713v1: Rethinking Closed-loop Training for Autonomous Driving
#
#  - 2210.10318v1: Gaussian-Bernoulli RBMs Without Tears
#
#  - 2210.03310v3: Scaling Forward Gradient With Local Losses
#
#  - 2210.02615v2: Learning to Reason With Relational Abstractions
#
#  - 2109.05675v4: Online Unsupervised Learning of Visual Representations and Categories
#
#  - 2104.03956v1: Just Label What You Need: Fine-Grained Active Selection for Perception
#   and Prediction through Partially Labeled Scenes
#
#  - 2101.06784v3: Exploring Adversarial Robustness of Multi-Sensor Perception Systems in
#   Self Driving
#
#  - 2101.06590v1: Cost-Efficient Online Hyperparameter Optimization
#
#  - 2101.06560v2: Adversarial Attacks On Multi-Agent Communication
#
#  - 2101.06553v2: Self-Supervised Representation Learning from Flow Equivariance
#
#  - 2101.06549v4: AdvSim: Generating Safety-Critical Scenarios for Self-Driving Vehicles
#
#  - 2101.06541v1: SceneGen: Learning to Generate Realistic Traffic Scenes
#
#  - 2012.05895v3: Probing Few-Shot Generalization with Attributes
#
#  - 2011.05289v1: Learning to Communicate and Correct Pose Errors
#
#  - 2011.01153v2: Perceive, Attend, and Drive: Learning Spatial Attention for Safe
#   Self-Driving
#
#  - 2010.07140v1: Theoretical bounds on estimation error for meta-learning
#
#  - 2009.04806v4: SketchEmbedNet: Learning Novel Concepts by Imitating Drawings
#
#  - 2008.05930v1: Perceive, Predict, and Plan: Safe Motion Planning Through Interpretable
#   Semantic Representations
#
#  - 2008.05927v1: End-to-end Contextual Perception and Prediction with Interaction
#   Transformer
#
#  - 2008.01342v2: LoCo: Local Contrastive Representation Learning
#
#  - 2007.05096v2: Multi-Agent Routing Value Iteration Network
#
#  - 2007.04546v3: Wandering Within a World: Online Contextualized Few-Shot Learning
#
#  - 2004.00543v2: Physically Realizable Adversarial Examples for LiDAR Object Detection
#
#  - 1910.11296v1: Identifying Unknown Instances for Autonomous Driving
#
#  - 1910.04650v2: Learning to Remember from a Multi-Task Teacher
#
#  - 1910.04586v1: Jointly Learnable Behavior and Trajectory Planning for Self-Driving
#   Vehicles
#
#  - 1907.13079v1: Deformable Filter Convolution for Point Cloud Reasoning
#
#  - 1810.07218v3: Incremental Few-Shot Learning with Attention Attractor Networks
#
#  - 1810.05749v3: Graph HyperNetworks for Neural Architecture Search
#
#  - 1803.09050v3: Learning to Reweight Examples for Robust Deep Learning
#
#  - 1803.02021v1: Understanding Short-Horizon Bias in Stochastic Meta-Optimization
#
#  - 1803.00676v1: Meta-Learning for Semi-Supervised Few-Shot Classification
#
#  - 1801.02108v2: SBNet: Sparse Blocks Network for Fast Inference
#
#  - 1707.04585v1: The Reversible Residual Network: Backpropagation Without Storing
#   Activations
#
#  - 1611.04520v2: Normalizing the Normalizers: Comparing and Extending Network
#   Normalization Schemes
#
#  - 1605.09410v5: End-to-End Instance Segmentation with Recurrent Attention
#
#  - 1505.02074v4: Exploring Models and Data for Image Question Answering

# %% [markdown]
# #### Pavel Izmailov: 25 (2, 5, 9, 13, 17)

# %%
query_dump_download_by_author('Pavel Izmailov', 100)
# Out:
# >> Getting papers from author: Pavel Izmailov
# >> Total number papers: 25
# >> Dumping Metadata and Downloading PDFs
#  - 2403.01272v1: Can a Confident Prior Replace a Cold Posterior?
#
#  - 2312.09390v1: Weak-to-Strong Generalization: Eliciting Strong Capabilities With Weak
#   Supervision
#
#  - 2306.11074v1: Simple and Fast Group Robustness by Automatic Feature Reweighting
#
#  - 2212.08013v2: FlexiViT: One Model for All Patch Sizes
#
#  - 2210.11369v1: On Feature Learning in the Presence of Spurious Correlations
#
#  - 2204.02937v2: Last Layer Re-Training is Sufficient for Robustness to Spurious
#   Correlations
#
#  - 2203.16481v1: On Uncertainty, Tempering, and Data Augmentation in Bayesian
#   Classification
#
#  - 2203.04449v2: Unsupervised learning of two-component nematicity from STM data on magic
#   angle bilayer graphene
#
#  - 2202.11678v3: Bayesian Model Selection, the Marginal Likelihood, and Generalization
#
#  - 2106.11905v2: Dangers of Bayesian Model Averaging under Covariate Shift
#
#  - 2106.05945v2: Does Knowledge Distillation Really Work?
#
#  - 2104.14421v1: What Are Bayesian Neural Network Posteriors Really Like?
#
#  - 2010.11882v2: Learning Invariances in Neural Networks
#
#  - 2006.08545v1: Why Normalizing Flows Fail to Detect Out-of-Distribution Data
#
#  - 2002.12880v3: Generalizing Convolutional Neural Networks for Equivariance to Lie
#   Groups on Arbitrary Continuous Data
#
#  - 2002.08791v4: Bayesian Deep Learning and a Probabilistic Perspective of Generalization
#
#  - 1912.13025v1: Semi-Supervised Learning with Normalizing Flows
#
#  - 1907.07504v1: Subspace Inference for Bayesian Deep Learning
#
#  - 1902.02476v2: A Simple Baseline for Bayesian Uncertainty in Deep Learning
#
#  - 1806.05594v3: There Are Many Consistent Explanations of Unlabeled Data: Why You Should
#   Average
#
#  - 1803.05407v3: Averaging Weights Leads to Wider Optima and Better Generalization
#
#  - 1802.10026v4: Loss Surfaces, Mode Connectivity, and Fast Ensembling of DNNs
#
#  - 1801.01928v2: Tensor Train decomposition on TensorFlow (T3F)
#
#  - 1710.07324v2: Scalable Gaussian Processes with Billions of Inducing Inputs via Tensor
#   Train Decomposition
#
#  - 1611.06132v1: Faster variational inducing input Gaussian process classification

# %% [markdown]
# #### Lerrel Pinto: 68 (14, 23, 34, 43, 53)

# %%
query_dump_download_by_author('Lerrel Pinto', 70)
# Out:
# >> Getting papers from author: Lerrel Pinto
# >> Total number papers: 68
# >> Dumping Metadata and Downloading PDFs
#  - 2410.02749v1: Training Language Models on Synthetic Edit Sequences Improves Code
#   Synthesis
#
#  - 2409.12192v1: DynaMo: In-Domain Dynamics Pretraining for Visuo-Motor Control
#
#  - 2409.08276v3: AnySkin: Plug-and-play Skin Sensing for Robotic Touch
#
#  - 2409.05865v1: Robot Utility Models: General Policies for Zero-Shot Deployment in New
#   Environments
#
#  - 2406.07539v2: BAKU: An Efficient Transformer for Multi-Task Policy Learning
#
#  - 2406.04318v1: Adaptive Sampling of k-Space in Magnetic Resonance for Rapid Pathology
#   Prediction
#
#  - 2403.07870v1: OPEN TEACH: A Versatile Teleoperation System for Robotic Manipulation
#
#  - 2403.03181v2: Behavior Generation with Latent Actions
#
#  - 2402.10211v3: Hierarchical State Space Models for Continuous Sequence-to-Sequence
#   Modeling
#
#  - 2401.12202v2: OK-Robot: What Really Matters in Integrating Open-Knowledge Models for
#   Robotics
#
#  - 2312.07540v3: diff History for Neural Language Agents
#
#  - 2311.16098v1: On Bringing Robots Home
#
#  - 2310.08864v8: Open X-Embodiment: Robotic Learning Datasets and RT-X Models
#
#  - 2310.08573v1: PolyTask: Learning Unified Policies through Behavior Distillation
#
#  - 2309.12300v1: See to Touch: Learning Tactile Dexterity through Visual Incentives
#
#  - 2306.12554v1: Improving Long-Horizon Imitation Through Instruction Prediction
#
#  - 2306.00942v2: Train Offline, Test Online: A Real Robot Learning Benchmark
#
#  - 2305.19240v2: NetHack is Hard to Hack
#
#  - 2303.12076v1: Dexterity from Touch: Self-Supervised Pre-Training of Tactile
#   Representations with Robotic Play
#
#  - 2303.01497v1: Teach a Robot to FISH: Versatile Imitation from One Minute of
#   Demonstrations
#
#  - 2210.10047v3: From Play to Policy: Conditional Behavior Generation from Uncurated
#   Robot Data
#
#  - 2210.06463v1: Holo-Dex: Teaching Dexterity with Immersive Mixed Reality
#
#  - 2210.05663v3: CLIP-Fields: Weakly Supervised Semantic Fields for Robotic Memory
#
#  - 2210.01116v1: That Sounds Right: Auditory Self-Supervision for Dynamic Robot
#   Manipulation
#
#  - 2208.02932v1: Human Decision Makings on Curriculum Reinforcement Learning with
#   Difficulty Adjustment
#
#  - 2206.15469v2: Watch and Match: Supercharging Imitation with Regularized Optimal
#   Transport
#
#  - 2206.11251v2: Behavior Transformers: Cloning $k$ modes with one stone
#
#  - 2203.13251v1: Dexterous Imitation Made Easy: A Learning-Based Framework for Efficient
#   Dexterous Manipulation
#
#  - 2203.11176v1: One After Another: Learning Incremental Skills for a Changing World
#
#  - 2203.08098v2: RB2: Robotic Manipulation Benchmarking with a Twist
#
#  - 2203.05549v1: Context is Everything: Implicit Identification for Dynamics Adaptation
#
#  - 2201.13425v3: Don't Change the Algorithm, Change the Data: Exploratory Data for
#   Offline Reinforcement Learning
#
#  - 2112.01511v2: The Surprising Effectiveness of Representation Learning for Visual
#   Imitation
#
#  - 2110.15191v1: URLB: Unsupervised Reinforcement Learning Benchmark
#
#  - 2107.09645v1: Mastering Visual Continuous Control: Improved Data-Augmented
#   Reinforcement Learning
#
#  - 2107.09046v1: Playful Interactions for Representation Learning
#
#  - 2104.02844v1: GEM: Group Enhanced Model for Learning Dynamical Control Systems
#
#  - 2103.16732v1: Simultaneous Navigation and Construction Benchmarking Environments
#
#  - 2102.13100v1: Task-Agnostic Morphology Evolution
#
#  - 2102.11271v2: Reinforcement Learning with Prototypical Representations
#
#  - 2012.09811v1: Learning Cross-Domain Correspondence for Control with Dynamics
#   Cycle-Consistency
#
#  - 2012.07975v3: Learning Visual Robotic Control Efficiently with Contrastive
#   Pre-training and Data Augmentation
#
#  - 2011.06698v1: Robust Policies via Mid-Level Visual Representations: An Experimental
#   Study in Manipulation and Navigation
#
#  - 2008.04899v1: Visual Imitation Made Easy
#
#  - 2007.04309v3: Self-Supervised Policy Adaptation during Deployment
#
#  - 2007.01851v1: Swoosh! Rattle! Thump! -- Actions that Sound
#
#  - 2006.09641v1: Automatic Curriculum Learning through Value Disagreement
#
#  - 2004.14990v5: Reinforcement Learning with Augmented Data
#
#  - 2004.04650v2: State-Only Imitation Learning for Dexterous Manipulation
#
#  - 2003.05436v1: Learning Predictive Representations for Deformable Objects Using
#   Contrastive Estimation
#
#  - 2003.01709v2: Hierarchically Decoupled Imitation for Morphological Transfer
#
#  - 2002.11708v1: Generalized Hindsight for Reinforcement Learning
#
#  - 1910.13439v2: Learning to Manipulate Deformable Objects without Demonstrations
#
#  - 1907.11740v1: Environment Probing Interaction Policies
#
#  - 1906.08236v1: PyRobot: An Open-source Robotics Framework for Research and Benchmarking
#
#  - 1903.00636v2: Robot Learning via Human Adversarial Games
#
#  - 1810.10654v1: Sample-Efficient Learning of Nonprehensile Manipulation Policies via
#   Physics-Based Informed State Distributions
#
#  - 1810.07121v1: Multiple Interactions Made Easy (MIME): Large Scale Demonstrations Data
#   for Imitation
#
#  - 1807.07049v1: Robot Learning in Homes: Improving Generalization and Reducing Dataset
#   Bias
#
#  - 1710.06542v1: Asymmetric Actor Critic for Image-Based Robot Learning
#
#  - 1709.08520v1: Predictive-State Decoders: Encoding the Future into Recurrent Networks
#
#  - 1708.01354v2: CASSL: Curriculum Accelerated Self-Supervised Learning
#
#  - 1704.05588v2: Learning to Fly by Crashing
#
#  - 1703.02702v1: Robust Adversarial Reinforcement Learning
#
#  - 1610.01685v1: Supervision via Competition: Robot Adversaries for Learning Tasks
#
#  - 1609.09025v1: Learning to Push by Grasping: Using multiple tasks for effective
#   learning
#
#  - 1604.01360v2: The Curious Robot: Learning Visual Representations via Physical
#   Interactions
#
#  - 1509.06825v1: Supersizing Self-supervision: Learning to Grasp from 50K Tries and 700
#   Robot Hours

# %% [markdown]
# #### Tal Linzen: 64 Papers (11, 19, 26, 35, 44)

# %%
query_dump_download_by_author('Tal Linzen', 1000)
# Out:
# >> Getting papers from author: Tal Linzen
# >> Total number papers: 64
# >> Dumping Metadata and Downloading PDFs
#  - 2409.04556v1: How Does Code Pretraining Affect Language Model Task Performance?
#
#  - 2407.04593v1: Testing learning hypotheses using neural networks by manipulating
#   learning data
#
#  - 2404.06214v2: [Call for Papers] The 2nd BabyLM Challenge: Sample-efficient pretraining
#   on a developmentally plausible corpus
#
#  - 2403.07202v1: SPAWNing Structural Priming Predictions from a Cognitively Motivated
#   Parser
#
#  - 2402.13956v3: Can You Learn Semantics Through Next-Word Prediction? The Case of
#   Entailment
#
#  - 2311.07811v2: In-context Learning Generalizes, But Not Always Robustly: The Case of
#   Syntax
#
#  - 2311.00445v2: A Systematic Comparison of Syllogistic Reasoning in Humans and Language
#   Models
#
#  - 2310.19956v2: The Impact of Depth on Compositional Generalization in Transformer
#   Language Models
#
#  - 2310.16142v1: A Language Model with Limited Memory Capacity Captures Interference in
#   Human Sentence Processing
#
#  - 2310.15151v1: Verb Conjugation in Transformers Is Determined by Linear Encodings of
#   Subject Number
#
#  - 2310.15040v1: SLOG: A Structural Generalization Benchmark for Semantic Parsing
#
#  - 2308.05576v3: Do Language Models' Words Refer?
#
#  - 2306.05969v1: Language Models Can Learn Exceptions to Syntactic Rules
#
#  - 2305.19905v1: How to Plant Trees in Language Models: Data and Architectural Effects on
#   the Emergence of Syntactic Inductive Biases
#
#  - 2301.11462v2: How poor is the stimulus? Evaluating hierarchical generalization in
#   neural networks trained on child-directed speech
#
#  - 2212.10769v1: Uncontrolled Lexical Exposure Leads to Overestimation of Compositional
#   Generalization in Pretrained Models
#
#  - 2210.14328v1: Causal Analysis of Syntactic Agreement Neurons in Multilingual Language
#   Models
#
#  - 2210.13569v2: Characterizing Verbatim Short-Term Memory in Neural Language Models
#
#  - 2210.12187v2: Syntactic Surprisal From Neural Models Predicts, But Underestimates,
#   Human Processing Difficulty From Syntactic Ambiguities
#
#  - 2209.12407v3: Entailment Semantics Can Be Extracted from an Ideal Language Model
#
#  - 2206.04615v3: Beyond the Imitation Game: Quantifying and extrapolating the
#   capabilities of language models
#
#  - 2205.03472v1: When a sentence does not introduce a discourse entity, Transformer-based
#   models still sometimes refer to it
#
#  - 2203.09397v1: Coloring the Blank Slate: Pre-training Imparts a Hierarchical Inductive
#   Bias to Sequence-to-sequence Models
#
#  - 2112.07610v2: Improving Compositional Generalization with Latent Structure and Data
#   Augmentation
#
#  - 2111.09509v1: How much do language models copy from their training data? Evaluating
#   linguistic novelty in text generation using RAVEN
#
#  - 2111.05013v1: Learning to Generalize Compositionally by Transferring Across Semantic
#   Parsing Tasks
#
#  - 2109.07848v1: The Language Model Understood the Prompt was Ambiguous: Probing
#   Syntactic Uncertainty Through Generation
#
#  - 2109.07020v1: Frequency Effects on Syntactic Rule Learning in Transformers
#
#  - 2109.06987v1: NOPE: A Corpus of Naturally-Occurring Presuppositions in English
#
#  - 2106.16163v2: The MultiBERTs: BERT Reproductions for Robustness Analysis
#
#  - 2106.06087v3: Causal Analysis of Syntactic Agreement Mechanisms in Neural Language
#   Models
#
#  - 2105.06965v3: Counterfactual Interventions Reveal the Causal Effect of Relative Clause
#   Representations on Agreement Prediction
#
#  - 2105.00071v3: Evaluating Attribution in Dialogue Systems: The BEGIN Benchmark
#
#  - 2104.07179v1: Does Putting a Linguist in the Loop Improve NLU Data Collection?
#
#  - 2010.05465v1: COGS: A Compositional Generalization Challenge Based on Semantic
#   Interpretation
#
#  - 2006.16324v1: Universal linguistic inductive biases via meta-learning
#
#  - 2005.00955v1: How Can We Accelerate Progress Towards Human-like Linguistic
#   Generalization?
#
#  - 2005.00187v2: Cross-Linguistic Syntactic Evaluation of Word Prediction Models
#
#  - 2005.00019v1: Representations of Syntax [MASK] Useful: Effects of Constituency and
#   Dependency Structure in Recursive LSTMs
#
#  - 2004.11999v1: Syntactic Data Augmentation Increases Robustness to Inference Heuristics
#
#  - 2004.10827v1: Syntactic Structure from Deep Learning
#
#  - 2001.03632v1: Does syntax need to grow on trees? Sources of hierarchical inductive
#   bias in sequence-to-sequence networks
#
#  - 1911.02969v2: BERTs of a feather do not generalize together: Large variability in
#   generalization across models with similar test set performance
#
#  - 1910.09113v3: Discovering the Compositional Structure of Vector Representations with
#   Role Learning Networks
#
#  - 1909.10579v1: Using Priming to Uncover the Organization of Syntactic Representations
#   in Neural Language Models
#
#  - 1909.00111v1: Quantity doesn't buy quality syntax with neural language models
#
#  - 1904.11544v2: Probing What Different NLP Tasks Teach Machines about Function Word
#   Comprehension
#
#  - 1904.04063v1: Analyzing and Interpreting Neural Networks for NLP: A Report on the
#   First BlackboxNLP Workshop
#
#  - 1903.06400v2: Studying the Inductive Biases of RNNs with Synthetic Variations of
#   Natural Languages
#
#  - 1902.01007v4: Right for the Wrong Reasons: Diagnosing Syntactic Heuristics in Natural
#   Language Inference
#
#  - 1901.04587v2: Human few-shot learning of compositional instructions
#
#  - 1812.08718v2: RNNs Implicitly Implement Tensor Product Representations
#
#  - 1811.12112v2: Non-entailed subsequences as a challenge for natural language inference
#
#  - 1810.11481v1: Can Entropy Explain Successor Surprisal Effects in Reading?
#
#  - 1809.04179v2: What can linguistics and deep learning contribute to each other?
#
#  - 1808.09930v2: A Neural Model of Adaptation in Reading
#
#  - 1808.09031v1: Targeted Syntactic Evaluation of Language Models
#
#  - 1807.06882v1: Distinct patterns of syntactic agreement errors in recurrent networks
#   and humans
#
#  - 1803.11138v1: Colorless green recurrent networks dream hierarchically
#
#  - 1802.09091v3: Revisiting the poverty of the stimulus: hierarchical generalization
#   without a hierarchical bias in recurrent neural networks
#
#  - 1711.06729v1: Phonological (un)certainty weights lexical activation
#
#  - 1706.03542v1: Exploring the Syntactic Abilities of RNNs with Multi-task Learning
#
#  - 1611.01368v1: Assessing the Ability of LSTMs to Learn Syntax-Sensitive Dependencies
#
#  - 1606.07736v1: Issues in evaluating semantic spaces using word analogies

# %% [markdown]
# #### Kyunghyun Cho: 272 (30, 64, 85, 106, 134)

# %%
query_dump_download_by_author('Kyunghyun Cho', 1000)
# Out:
# >> Getting papers from author: Kyunghyun Cho
# >> Total number papers: 272
# >> Dumping Metadata and Downloading PDFs
#  - 2409.18581v1: Using Deep Autoregressive Models as Causal Inference Engines
#
#  - 2409.01931v2: On the design space between molecular mechanics and machine learning
#   force fields
#
#  - 2408.16218v1: Targeted Cause Discovery with Data-Driven Learning
#
#  - 2408.13430v1: Analysis of the ICML 2023 Ranking Data: Can Authors' Opinions of Their
#   Own Papers Assist Peer Review in Machine Learning?
#
#  - 2408.00165v3: Non-convolutional Graph Neural Networks
#
#  - 2407.18134v2: $\mathbb{X}$-Sample Contrastive Loss: Improving Contrastive Learning
#   with Sample Similarity Graphs
#
#  - 2407.21028v1: Antibody DomainBed: Out-of-Distribution Generalization in Therapeutic
#   Protein Design
#
#  - 2407.02736v1: MentalAgora: A Gateway to Advanced Personalized Care in Mental Health
#   through Multi-Agent Debating and Attribute Control
#
#  - 2407.00236v1: Closed-Form Test Functions for Biophysical Sequence Optimization
#   Algorithms
#
#  - 2406.17744v1: Following Length Constraints in Instructions
#
#  - 2406.14876v1: Training Greedy Policy for Proposal Batch Selection in Expensive
#   Multi-Objective Combinatorial Optimization
#
#  - 2406.10119v1: Modified Risk Formulation for Improving the Prediction of Knee
#   Osteoarthritis Progression
#
#  - 2407.13942v1: Harmful Suicide Content Detection
#
#  - 2406.02585v1: Contextual Counting: A Mechanistic Study of Transformers on a
#   Quantitative Task
#
#  - 2405.19534v3: Preference Learning Algorithms Do Not Learn Preference Rankings
#
#  - 2405.18075v1: Implicitly Guided Design with PropEn: Match your Data to Follow the
#   Gradient
#
#  - 2405.17613v1: A Framework for Multi-modal Learning: Jointly Modeling Inter- &
#   Intra-Modality Dependencies
#
#  - 2405.08793v1: A Brief Introduction to Causal Inference in Machine Learning
#
#  - 2405.02784v1: MR-Transformer: Vision Transformer for Total Knee Replacement Prediction
#   Using Magnetic Resonance Imaging
#
#  - 2404.19733v3: Iterative Reasoning Preference Optimization
#
#  - 2405.00069v1: Estimation of Time-to-Total Knee Replacement Surgery
#
#  - 2404.15928v2: Generalization Measures for Zero-Shot Cross-Lingual Transfer
#
#  - 2404.01954v2: HyperCLOVA X Technical Report
#
#  - 2403.09066v2: Hyperparameters in Continual Learning: A Reality Check
#
#  - 2401.10020v2: Self-Rewarding Language Models
#
#  - 2401.04575v2: Let's Go Shopping (LGS) -- Web-Scale Image-Text Dataset for Visual
#   Concept Understanding
#
#  - 2312.09323v3: Perspectives on the State and Future of Deep Learning - 2023
#
#  - 2311.09497v1: Peer Reviews of Peer Reviews: A Randomized Controlled Trial and Other
#   Experiments
#
#  - 2311.09480v2: Show Your Work with Confidence: Confidence Bands for Tuning Curves
#
#  - 2311.05020v2: First Tragedy, then Parse: History Repeats Itself in the New Era of
#   Large Language Models
#
#  - 2310.04824v1: PaperCard for Reporting Machine Assistance in Academic Writing
#
#  - 2310.03024v2: AstroCLIP: A Cross-Modal Foundation Model for Galaxies
#
#  - 2310.02994v1: Multiple Physics Pretraining for Physical Surrogate Models
#
#  - 2310.02989v1: xVal: A Continuous Number Encoding for Large Language Models
#
#  - 2309.07311v5: Sudden Drops in the Loss: Syntax Acquisition, Phase Transitions, and
#   Simplicity Bias in MLMs
#
#  - 2309.01670v1: Blind Biological Sequence Denoising with Self-Supervised Set Learning
#
#  - 2308.09543v3: Latent State Models of Training Dynamics
#
#  - 2308.09248v2: Active and Passive Causal Inference Learning
#
#  - 2308.06246v1: ARGUS: Visualization of AI-Assisted Task Guidance in AR
#
#  - 2308.06125v1: Improving Joint Speech-Text Representations Without Alignment
#
#  - 2308.05027v2: AbDiffuser: Full-Atom Generation of in vitro Functioning Antibodies
#
#  - 2307.14117v2: Leveraging Implicit Feedback from Deployment Data in Dialogue
#
#  - 2307.07051v1: Making the Most Out of the Limited Context Length: Predictive Power
#   Varies with Clinical Note Type and Note Section
#
#  - 2306.13588v3: System-Level Natural Language Feedback
#
#  - 2306.13276v1: On Sensitivity and Robustness of Normalization Schemes to Input
#   Distribution Shifts in Automatic MR Image Diagnosis
#
#  - 2306.12360v2: Protein Discovery with Discrete Walk-Jump Sampling
#
#  - 2306.05101v2: Regularizing with Pseudo-Negatives for Continual Self-Supervised
#   Learning
#
#  - 2306.00344v2: BOtied: Multi-objective Bayesian optimization with tied multivariate
#   ranks
#
#  - 2305.20009v2: Protein Design with Guided Discrete Diffusion
#
#  - 2305.14279v4: Two Failures of Self-Consistency in the Multi-Step Reasoning of LLMs
#
#  - 2305.07170v1: Towards Understanding and Improving GFlowNet Training
#
#  - 2304.11053v1: A Comparison of Semi-Supervised Learning Techniques for Streaming ASR at
#   Scale
#
#  - 2303.16755v3: Training Language Models with Language Feedback at Scale
#
#  - 2303.16749v2: Improving Code Generation by Training with Natural Language Feedback
#
#  - 2303.12065v1: Emulating radiation transport on cosmological scale using a denoising
#   Unet
#
#  - 2302.04369v1: Unsupervised Learning of Initialization in Deep Neural Networks via
#   Maximum Mean Discrepancy
#
#  - 2301.04327v1: Dual Learning for Large Vocabulary On-Device ASR
#
#  - 2212.10504v2: Can Current Task-oriented Dialogue Models Automate Real-world Scenarios
#   in the Wild?
#
#  - 2212.10020v3: On the Blind Spots of Model-Based Evaluation Metrics for Text Generation
#
#  - 2211.10831v1: Joint Embedding Predictive Architectures Focus on Slow Features
#
#  - 2211.07047v2: Language Model Classifier Aligns Better with Physician Word Sensitivity
#   than XGBoost on Readmission Prediction
#
#  - 2210.10838v1: A Pareto-optimal compositional energy-based model for sampling and
#   optimization of protein sequences
#
#  - 2210.05112v1: HUE: Pretrained Model and Dataset for Understanding Hanja Documents of
#   Ancient Korea
#
#  - 2210.04096v1: PropertyDAG: Multi-objective Bayesian optimization of partially ordered,
#   mixed-variable properties for biological sequence design
#
#  - 2210.00660v3: A Non-monotonic Self-terminating Language Model
#
#  - 2208.13191v1: Towards Disentangled Speech Representations
#
#  - 2207.02093v3: Predicting Out-of-Domain Generalization with Neighborhood Invariance
#
#  - 2206.13163v1: Endowing Language Models with Multimodal Knowledge Graph Representations
#
#  - 2205.12411v5: Linear Connectivity Reveals Generalization Strategies
#
#  - 2205.10019v5: Translating Hanja Historical Documents to Contemporary Korean and
#   English
#
#  - 2205.04259v1: Multi-segment preserving sampling for deep manifold sampler
#
#  - 2204.14146v4: Training Language Models with Language Feedback
#
#  - 2204.13509v2: On the Effect of Pretraining Corpora on In-context Learning by a
#   Large-scale Language Model
#
#  - 2204.11817v3: Translation between Molecules and Natural Language
#
#  - 2204.07184v1: Separating the World and Ego Models for Self-Driving
#
#  - 2202.05306v3: Characterizing and overcoming the greedy nature of learning in
#   multi-modal deep neural networks
#
#  - 2202.04136v3: Generative multitask learning mitigates target-causing confounding
#
#  - 2202.03651v2: Causal Scene BERT: Improving object detection by searching for
#   challenging groups of data
#
#  - 2112.13969v1: LINDA: Unsupervised Learning to Interpolate in Natural Language
#   Processing
#
#  - 2112.08914v2: Characterizing and addressing the issue of oversmoothing in neural
#   autoregressive sequence modeling
#
#  - 2112.08670v2: Amortized Noisy Channel Neural Machine Translation
#
#  - 2111.08656v2: Causal Effect Variational Autoencoder with Uniform Treatment
#
#  - 2111.07393v1: DEEP: DEnoising Entity Pre-training for Neural Machine Translation
#
#  - 2111.02508v1: AlphaD3M: Machine Learning Pipeline Synthesis
#
#  - 2110.09646v1: Monotonic Simultaneous Translation with Chunk-wise Reordering and
#   Refinement
#
#  - 2109.09888v2: Chemical-Reaction-Aware Molecule Representation Learning
#
#  - 2109.08227v1: Stereo Video Reconstruction Without Explicit Depth Maps for Endoscopic
#   Surgery
#
#  - 2109.02772v2: An Empirical Study on Few-shot Knowledge Probing for Pretrained Language
#   Models
#
#  - 2108.04800v3: Meta-repository of screening mammography classifiers
#
#  - 2107.12329v2: AASAE: Augmentation-Augmented Stochastic Autoencoders
#
#  - 2106.05459v1: Mode recovery in neural autoregressive sequence modeling
#
#  - 2106.00840v1: Comparing Test Sets with Item Response Theory
#
#  - 2105.11447v1: True Few-Shot Learning with Language Models
#
#  - 2105.09680v4: KLUE: Korean Language Understanding Evaluation
#
#  - 2104.06344v3: The Future is not One-dimensional: Complex Event Schema Induction by
#   Graph Modeling for Event Prediction
#
#  - 2104.01112v2: NaturalProofs: Mathematical Theorem Proving in Natural Language
#
#  - 2103.03872v1: Rissanen Data Analysis: Examining Dataset Characteristics via
#   Description Length
#
#  - 2102.07813v2: Online hyperparameter optimization by real-time recurrent learning
#
#  - 2102.00863v1: Self-Supervised Equivariant Scene Synthesis from Video
#
#  - 2101.09458v2: Decoupled Exploration and Exploitation Policies for Sample-Efficient
#   Reinforcement Learning
#
#  - 2012.14193v3: Catastrophic Fisher Explosion: Early Phase Fisher Matrix Impacts
#   Generalization
#
#  - 2012.01711v1: A Study on the Autoregressive and non-Autoregressive Multi-label
#   Learning
#
#  - 2011.14036v1: Differences between human and machine perception in medical diagnosis
#
#  - 2011.05787v1: Learned Equivariant Rendering without Transformation Supervision
#
#  - 2011.00615v1: Improving Conversational Question Answering Systems after Deployment
#   using Feedback-Weighted Learning
#
#  - 2010.07003v2: Length-Adaptive Transformer: Train Once with Length Drop, Use Anytime
#   with Search
#
#  - 2009.10195v2: SSMBA: Self-Supervised Manifold Based Data Augmentation for Improving
#   Out-of-Domain Robustness
#
#  - 2009.09282v1: Reducing false-positive biopsies with deep neural networks that utilize
#   local and global information in screening mammograms
#
#  - 2009.07783v3: Generative Language-Grounded Policy in Vision-and-Language Navigation
#   with Bayes' Rule
#
#  - 2009.07368v2: Evaluating representations by the complexity of learning low-loss
#   predictors
#
#  - 2009.07243v1: A Systematic Characterization of Sampling Algorithms for Open-ended
#   Language Generation
#
#  - 2009.07177v1: Iterative Refinement in the Continuous Space for Non-Autoregressive
#   Neural Machine Translation
#
#  - 2009.00104v1: A Framework For Contrastive Self-Supervised Learning And Designing A New
#   Approach
#
#  - 2008.09150v2: VisualSem: A High-quality Knowledge Graph for Vision and Language
#
#  - 2007.07779v3: AdapterHub: A Framework for Adapting Transformers
#
#  - 2007.07846v1: Covidex: Neural Ranking Models and Keyword Search Infrastructure for the
#   COVID-19 Open Research Dataset
#
#  - 2006.03158v2: MLE-guided parameter search for task loss minimization in neural
#   sequence modeling
#
#  - 2005.00247v3: AdapterFusion: Non-Destructive Task Composition for Transfer Learning
#
#  - 2004.14120v2: Learning Non-Monotonic Automatic Post-Editing of Translations from Human
#   Orderings
#
#  - 2004.13304v1: Learning to Learn Morphological Inflection for Resource-Poor Languages
#
#  - 2004.11339v1: Rapidly Bootstrapping a Question Answering Dataset for COVID-19
#
#  - 2004.05125v1: Rapidly Deploying a Neural Search Engine for the COVID-19 Open Research
#   Dataset: Preliminary Thoughts and Lessons Learned
#
#  - 2004.04228v1: Asking and Answering Questions to Evaluate the Factual Consistency of
#   Summaries
#
#  - 2003.10041v1: Understanding the robustness of deep neural network classifiers for
#   breast cancer screening
#
#  - 2002.09758v3: Unsupervised Question Decomposition for Question Answering
#
#  - 2002.09572v1: The Break-Even Point on Optimization Trajectories of Deep Neural
#   Networks
#
#  - 2002.07233v1: On the Discrepancy between Density Estimation and Sequence Generation
#
#  - 2002.07613v1: An interpretable classifier for high-resolution breast cancer screening
#   images utilizing weakly supervised localization
#
#  - 2002.02492v2: Consistency of a Recurrent Language Model With Respect to Incomplete
#   Decoding
#
#  - 2001.08687v1: Navigation-Based Candidate Expansion and Pretrained Language Models for
#   Citation Recommendation
#
#  - 1911.03860v2: Don't Say That! Making Inconsistent Dialogue Unlikely with Unlikelihood
#   Training
#
#  - 1910.14424v1: Multi-Stage Document Ranking with BERT
#
#  - 1910.11424v3: Capacity, Bandwidth, and Compositionality in Emergent Language Learning
#
#  - 1910.07117v5: Analyzing the Forgetting Problem in the Pretrain-Finetuning of Dialogue
#   Response Models
#
#  - 1910.01727v2: Generalized Inner Loop Meta-Learning
#
#  - 1909.11299v2: Mixout: Effective Regularization to Finetune Large-scale Pretrained
#   Language Models
#
#  - 1909.10056v1: Inducing Constituency Trees through Neural Machine Translation
#
#  - 1909.05863v1: Finding Generalizable Evidence by Learning to Convince Q&A Models
#
#  - 1909.04499v1: Countering Language Drift via Visual Grounding
#
#  - 1909.03341v2: Neural Machine Translation with Byte-Level Subwords
#
#  - 1909.01522v2: Towards Realistic Practices In Low-Resource Natural Language Processing:
#   The Development Set
#
#  - 1908.09357v3: Dynamics-aware Embeddings
#
#  - 1908.07181v5: Latent-Variable Non-Autoregressive Neural Machine Translation with
#   Deterministic Inference Using a Delta Posterior
#
#  - 1908.04319v2: Neural Text Generation with Unlikelihood Training
#
#  - 1908.00615v1: Improving localization-based approaches for breast cancer screening exam
#   classification
#
#  - 1907.13057v1: Screening Mammogram Classification with Prior Exams
#
#  - 1907.04944v2: Can Unconditional Language Models Recover Arbitrary Sentences?
#
#  - 1907.02649v1: A Unified Framework of Online Learning Algorithms for Training Recurrent
#   Neural Networks
#
#  - 1906.03697v2: Deep Unsupervised Drum Transcription
#
#  - 1906.02846v2: Globally-Aware Multiple Instance Classifier for Breast Cancer Screening
#
#  - 1906.01181v1: Improved Zero-shot Neural Machine Translation via Ignoring Spurious
#   Correlations
#
#  - 1906.00141v2: Multi-Turn Beam Search for Neural Dialogue Modeling
#
#  - 1905.12790v2: A Generalized Framework of Sequence Generation with Application to
#   Undirected Sequence Models
#
#  - 1905.12100v1: Using local plasticity rules to train recurrent neural networks
#
#  - 1905.10930v2: Sequential Graph Dependency Parser
#
#  - 1905.10345v1: Automatic Machine Learning by Pipeline Synthesis using Model-Based
#   Reinforcement Learning and a Grammar
#
#  - 1905.05843v1: Task-Driven Data Verification via Gradient Descent
#
#  - 1904.12935v1: Advancing GraphSAGE with A Data-Driven Node Sampling
#
#  - 1904.08375v2: Document Expansion by Query Prediction
#
#  - 1904.00314v2: Molecular geometry prediction using a deep generative graph neural
#   network
#
#  - 1903.08297v1: Deep Neural Networks Improve Radiologists' Performance in Breast Cancer
#   Screening
#
#  - 1903.04715v1: Context-Aware Learning for Neural Machine Translation
#
#  - 1903.04476v1: Continual Learning via Neural Pruning
#
#  - 1902.07296v1: Augmentation for small object detection
#
#  - 1902.04094v2: BERT has a Mouth, and It Must Speak: BERT as a Markov Random Field
#   Language Model
#
#  - 1902.02192v3: Non-Monotonic Sequential Text Generation
#
#  - 1902.01370v3: Insertion-based Decoding with automatically Inferred Generation Order
#
#  - 1901.08706v2: Emergent Linguistic Phenomena in Multi-Agent Communication Games
#
#  - 1901.04085v5: Passage Re-ranking with BERT
#
#  - 1811.00907v3: Importance of Search and Evaluation Strategies in Neural Dialogue
#   Modeling
#
#  - 1811.00671v2: Dialogue Natural Language Inference
#
#  - 1810.00150v2: Directional Analysis of Stochastic Gradient Descent via von Mises-Fisher
#   Distributions in Deep learning
#
#  - 1809.07124v2: Pommerman: A Multi-Agent Playground
#
#  - 1809.04640v2: Jump to better conclusions: SCAN both left and right
#
#  - 1808.10000v1: Grammar Induction with Neural Language Models: An Unusual Replication
#
#  - 1808.08437v1: Meta-Learning for Low-Resource Neural Machine Translation
#
#  - 1807.06919v5: Backplay: "Man muss immer umkehren"
#
#  - 1806.06875v1: Learning Distributed Representations from Reviews for Collaborative
#   Filtering
#
#  - 1805.12352v2: DialogWAE: Multimodal Response Generation with Conditional Wasserstein
#   Auto-Encoder
#
#  - 1805.08249v3: Classifier-agnostic saliency map extraction
#
#  - 1805.00108v3: Conditional molecular design with deep generative models
#
#  - 1804.07983v2: Dynamic Meta-Embeddings for Improved Sentence Representations
#
#  - 1804.07915v2: A Stable and Effective Learning Strategy for Trainable Greedy Decoding
#
#  - 1804.07875v1: Multi-lingual Common Semantic Space Construction via Cluster-consistent
#   Word Embedding
#
#  - 1804.07178v2: Vehicle Communication Strategies for Simulated Highway Driving
#
#  - 1804.04264v1: Training a Ranking Function for Open-Domain Question Answering
#
#  - 1803.11407v2: Fine-Grained Attention Mechanism for Neural Machine Translation
#
#  - 1803.07038v2: Controlling Decoding for More Abstractive Summaries with Copy-Based
#   Networks
#
#  - 1802.09502v1: Retrieval-Augmented Convolutional Neural Networks for Improved
#   Robustness against Adversarial Examples
#
#  - 1802.06901v3: Deterministic Non-Autoregressive Neural Sequence Modeling by Iterative
#   Refinement
#
#  - 1711.05246v2: Loss Functions for Multiset Prediction
#
#  - 1711.05165v1: Saliency-based Sequential Image Attention with Multiset Prediction
#
#  - 1711.03674v1: Breast density classification with deep convolutional neural networks
#
#  - 1710.11041v2: Unsupervised Neural Machine Translation
#
#  - 1710.04908v2: Graph Convolutional Networks for Classification with a Structured Label
#   Space
#
#  - 1710.06922v2: Emergent Translation in Multi-Agent Communication
#
#  - 1709.07545v1: Attention-based Mixture Density Recurrent Networks for History-based
#   Recommendation
#
#  - 1709.04396v2: A Tutorial on Deep Learning for Music Information Retrieval
#
#  - 1709.01922v3: A Comparison of Audio Signal Preprocessing Methods for Deep Neural
#   Networks on Music Tagging
#
#  - 1707.08939v1: Strawman: an Ensemble of Deep Bag-of-Ngrams for Sentiment Analysis
#
#  - 1707.01066v1: Zero-Shot Transfer Learning for Event Extraction
#
#  - 1706.02361v3: The Effects of Noisy Labels on Deep Convolutional Neural Networks for
#   Music Tagging
#
#  - 1705.10369v4: Emergent Communication in a Multi-Modal, Multi-Step Referential Game
#
#  - 1705.07267v2: Search Engine Guided Non-Parametric Neural Machine Translation
#
#  - 1704.06176v5: Segmentation of the Proximal Femur from MR Images using Deep
#   Convolutional Neural Networks
#
#  - 1704.05179v3: SearchQA: A New Q&A Dataset Augmented with Context from a Search Engine
#
#  - 1704.05135v1: Does Neural Machine Translation Benefit from Larger Context?
#
#  - 1704.04572v4: Task-Oriented Query Reformulation with Reinforcement Learning
#
#  - 1703.09179v4: Transfer learning for music classification and regression tasks
#
#  - 1703.07047v3: High-Resolution Breast Cancer Screening with Multi-View Deep
#   Convolutional Neural Networks
#
#  - 1703.04357v1: Nematus: a Toolkit for Neural Machine Translation
#
#  - 1702.08431v4: Boundary-Seeking Generative Adversarial Networks
#
#  - 1702.03525v2: Learning to Parse and Translate Improves Neural Machine Translation
#
#  - 1702.02429v1: Trainable Greedy Decoding for Neural Machine Translation
#
#  - 1702.00748v2: QCD-Aware Recursive Neural Networks for Jet Physics
#
#  - 1611.01268v1: Semantic Noise Modeling for Better Representation Learning
#
#  - 1611.00864v2: Spatio-temporal Dynamics of Intrinsic Networks in Functional Magnetic
#   Imaging Data Using Recurrent Neural Networks
#
#  - 1610.03017v3: Fully Character-Level Neural Machine Translation without Explicit
#   Segmentation
#
#  - 1610.00388v3: Learning to Translate in Real-time with Neural Machine Translation
#
#  - 1609.04243v3: Convolutional Recurrent Neural Networks for Music Classification
#
#  - 1608.04868v2: Towards Music Captioning: Generating Music Playlist Descriptions
#
#  - 1607.00578v1: Context-Dependent Word Representation for Neural Machine Translation
#
#  - 1607.00036v2: Dynamic Neural Turing Machine with Soft and Hard Addressing Schemes
#
#  - 1606.04754v1: A Correlational Encoder Decoder Architecture for Pivot Based Sequence
#   Generation
#
#  - 1606.04164v1: Zero-Resource Translation with Multi-Lingual Neural Machine Translation
#
#  - 1606.02680v1: First Result on Arabic Neural Machine Translation
#
#  - 1606.02012v1: Can neural machine translation do simultaneous translation?
#
#  - 1606.01865v2: Recurrent Neural Networks for Multivariate Time Series with Missing
#   Values
#
#  - 1606.01700v2: Gated Word-Character Recurrent Language Model
#
#  - 1605.06450v1: Query-Efficient Imitation Learning for End-to-End Autonomous Driving
#
#  - 1605.03835v1: Noisy Parallel Approximate Decoding for Conditional Recurrent Language
#   Model
#
#  - 1605.02688v1: Theano: A Python framework for fast computation of mathematical
#   expressions
#
#  - 1603.06147v4: A Character-Level Decoder without Explicit Segmentation for Neural
#   Machine Translation
#
#  - 1602.03483v1: Learning Distributed Representations of Sentences from Unlabelled Data
#
#  - 1602.02261v2: End-to-End Goal-Driven Web Navigation
#
#  - 1602.00367v1: Efficient Character-level Document Classification by Combining
#   Convolution and Recurrent Layers
#
#  - 1601.01073v1: Multi-Way, Multilingual Neural Machine Translation with a Shared
#   Attention Mechanism
#
#  - 1511.07916v1: Natural Language Understanding with Distributed Representation
#
#  - 1511.07053v3: ReSeg: A Recurrent Neural Network-based Model for Semantic Segmentation
#
#  - 1511.06428v4: A Controller-Recognizer Framework: How necessary is recognition for
#   control?
#
#  - 1511.06425v2: First Step toward Model-Free, Anonymous Object Tracking with Recurrent
#   Neural Networks
#
#  - 1511.06382v6: Iterative Refinement of the Approximate Posterior for Directed Belief
#   Networks
#
#  - 1511.04590v5: Oracle performance for visual captioning
#
#  - 1511.03729v2: Larger-Context Language Modelling
#
#  - 1507.01053v1: Describing Multimedia Content using Attention-based Encoder--Decoder
#   Networks
#
#  - 1506.07503v1: Attention-Based Models for Speech Recognition
#
#  - 1505.00393v3: ReNet: A Recurrent Neural Network Based Alternative to Convolutional
#   Networks
#
#  - 1504.00548v4: Learning to Understand Phrases by Embedding the Dictionary
#
#  - 1503.03535v2: On Using Monolingual Corpora in Neural Machine Translation
#
#  - 1502.08029v5: Describing Videos by Exploiting Temporal Structure
#
#  - 1502.03044v3: Show, Attend and Tell: Neural Image Caption Generation with Visual
#   Attention
#
#  - 1502.02367v4: Gated Feedback Recurrent Neural Networks
#
#  - 1412.6448v4: Embedding Word Similarity with Neural Machine Translation
#
#  - 1412.3555v1: Empirical Evaluation of Gated Recurrent Neural Networks on Sequence
#   Modeling
#
#  - 1412.2007v2: On Using Very Large Target Vocabulary for Neural Machine Translation
#
#  - 1412.1602v1: End-to-end Continuous Speech Recognition using Attention-based Recurrent
#   NN: First Results
#
#  - 1410.0718v2: Not All Neural Embeddings are Born Equal
#
#  - 1409.1259v2: On the Properties of Neural Machine Translation: Encoder-Decoder
#   Approaches
#
#  - 1409.1257v2: Overcoming the Curse of Sentence Length for Neural Machine Translation
#   using Automatic Segmentation
#
#  - 1409.0585v1: On the Equivalence Between Deep NADE and Generative Stochastic Networks
#
#  - 1409.0473v7: Neural Machine Translation by Jointly Learning to Align and Translate
#
#  - 1406.7362v1: Exponentially Increasing the Capacity-to-Computation Ratio for
#   Conditional Computation in Deep Learning
#
#  - 1406.2572v1: Identifying and attacking the saddle point problem in high-dimensional
#   non-convex optimization
#
#  - 1406.1485v3: Iterative Neural Autoregressive Distribution Estimator (NADE-k)
#
#  - 1406.1078v3: Learning Phrase Representations using RNN Encoder-Decoder for
#   Statistical Machine Translation
#
#  - 1402.1869v2: On the Number of Linear Regions of Deep Neural Networks
#
#  - 1312.6026v5: How to Construct Deep Recurrent Neural Networks
#
#  - 1311.6184v4: Bounding the Test Log-Likelihood of Generative Models
#
#  - 1311.1780v7: Learned-Norm Pooling for Deep Feedforward and Recurrent Neural Networks
#
#  - 1306.3874v2: Classifying and Visualizing Motion Capture Sequences using Deep Neural
#   Networks
#
#  - 1306.2801v4: Understanding Dropout: Training Multi-Layer Perceptrons with Auxiliary
#   Independent Stochastic Neurons
#
#  - 1301.3468v6: Boltzmann Machines and Denoising Autoencoders for Image Denoising

# %% [markdown]
# ## Test Llama Parse Per-Author on Most Recent Papers

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
MAX_PARSE=1

# %%
load_author_select_recent_llama_parse("Tal Linzen", num_years=5, max_parse=MAX_PARSE)
# Out:
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 32bd492a-bde1-40f5-9188-83899fcd3e4d
#  - 39 blocks for paper: Testing learning hypotheses using neural networks by manipulating
#   learning data
# >> Reached parse: 1, break

# %%
load_author_select_recent_llama_parse("Pavel Izmailov", num_years=5, max_parse=MAX_PARSE)
# Out:
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 9ea86b08-73de-42fe-bf46-bb468919d185
# . - 19 blocks for paper: Can a Confident Prior Replace a Cold Posterior?
# >> Reached parse: 1, break

# %%
load_author_select_recent_llama_parse("Lerrel Pinto", num_years=5, max_parse=MAX_PARSE)
# Out:
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 381ddbea-be48-4d4a-b9f6-c3ad488e41bc
# ... - 24 blocks for paper: Training Language Models on Synthetic Edit Sequences Improves Code
#   Synthesis
# >> Reached parse: 1, break

# %%
load_author_select_recent_llama_parse("Kyunghyun Cho", num_years=5, max_parse=MAX_PARSE)
# Out:
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id fb74496b-3199-45ef-ae27-43e4da62eff3
# .... - 16 blocks for paper: Using Deep Autoregressive Models as Causal Inference Engines
# >> Reached parse: 1, break

# %%
load_author_select_recent_llama_parse("Mengye Ren", num_years=5, max_parse=MAX_PARSE)
# Out:
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id a9294576-9c4e-480f-a3cf-ed9397a3c18a
# .... - 22 blocks for paper: PooDLe: Pooled and dense self-supervised learning from naturalistic
#   videos
# >> Reached parse: 1, break

# %%
load_author_select_recent_llama_parse("Rajesh Ranganath", num_years=5, max_parse=MAX_PARSE)
# Out:
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 5bf0d770-548a-44f8-bbf1-8a85c93697c0
# .. - 27 blocks for paper: What's the score? Automated Denoising Score Matching for Nonlinear
#   Diffusions
# >> Reached parse: 1, break

# %%
load_author_select_recent_llama_parse("Eunsol Choi", num_years=5, max_parse=MAX_PARSE)
# Out:
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 3b6ede8f-76c1-42d1-b937-da835e5a4465
# .. - 20 blocks for paper: Open-World Evaluation for Retrieving Diverse Perspectives
# >> Reached parse: 1, break

# %%
load_author_select_recent_llama_parse("He He", num_years=5, max_parse=MAX_PARSE)
# Out:
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id e8430822-c9a1-4489-8438-75d39dd79d89
# ........ - 23 blocks for paper: Language Models Learn to Mislead Humans via RLHF
# >> Reached parse: 1, break

# %%
pdfn = '2409.04556v1'
read_doc = fu.load_file(f'{PARSED_PDF_DIR}{pdfn}.pkl')
print(read_doc[1].text)
# Out:
# Establishing a causal relationship between code pretraining and downstream performance is difficult. Earlier studies have tackled these questions by comparing off-the-shelf code and no-code models (see, inter alia, Kim et al. 2024; Coda-Forno et al. 2024). Such observational studies are limited by the design choices of model creators and the availability of information about hyperparameters and training data. Many of the models typically surveyed are proprietary, and don’t disclose this information. While pairs of open-source models differing only in their pretraining corpora do exist, such as Llama 2 & Code Llama (Touvron et al., 2023; Roziere et al., 2023) or Gemma & CodeGemma (Gemma Team et al., 2024; Google, 2024), they often come with two important caveats: first, the code-variants of the models are derived by taking the non-code variants and conducting additional pretraining on code data, meaning the comparisons cannot control for total data volume; second, each pair treats the inclusion of code data as a binary variable, either present or absent, frustrating attempts to explore how changes in the amount of code influence downstream behavior.
#
# We address these issues directly. We construct datasets that mix natural-language and source-code data at varying ratios, treating code inclusion as a continuous variable. We then pretrain language models of equal size on these parameterized datasets in two different experimental setups: a competitive setting where we keep the total volume of training data constant and vary the percentage allocated between code and natural language; and an additive setting where we keep the volume of language data constant and add additional amounts of code on top.
#
# Previous work has found that augmenting training data with synthetic formal languages instantiating compositional patterns can improve compositional generalization (Papadimitriou & Jurafsky, 2023; Yao & Koller, 2024; Lindemann et al., 2024). Like formal languages, source code has a number of qualities which may aid models on seemingly-unrelated tasks: it is highly structured, by virtue of its conformance to the syntax of the programming language its written in; it is generally high-quality, owing to the use of linting and bug-checking tools and programming methodologies employed by its authors; it has interpretable semantics which is grounded by the functionality it describes; and, notably for compositionality, it contains instances of identical arguments and functions (e.g., variable names and method signatures). Informed by these observations, we evaluate our trained models for compositional generalization by finetuning them on three compositional generalization benchmarks (COGS, COGS-vf, and English Passivization). We also measure their performance on a broad array of tasks from BigBench to see how well code helps or hurts performance on unrelated domains.
#
# We find that including code in a model’s pretraining corpus has noticeable impacts on its performance on downstream tasks, in varying directions. Higher code mixtures improve performance in arithmetic and compositionality in domains whose output has formal structure (like semantic parsing). Conversely, increased exposure to code can harm language model performance on purely-linguistic tasks and tasks involving factual knowledge. We conduct permutation tests to study the impact of pretraining on downstream tasks and show that code pretraining increases the variance on task performance while raising the performance on the upper-quartile of tasks.
#
# # 2 Related Work
#
# Earlier work has studied whether pretraining on code is beneficial for non-programming tasks. Observational studies have looked at the impact of code on downstream performance post-hoc. Fu & Khot (2022) speculated that code pretraining is at least partially responsible for the improvement in capabilities between the -001 and -002 series of GPT-3(.5) models, specifically highlighting chain-of-thought reasoning, long-term dependency sensitivity, and “complex reasoning” as likely resulting from code pretraining. Yang et al. (2024b) provides a broad study of how code impacts language model capabilities, arguing that code improves complex reasoning and structured data understanding. Mueller et al. (2024) shows that code pretraining improves generalization on syntax-sensitive in-context learning tasks. By contrast, Coda-Forno et al. (2024), in an observational study, conclude that code pretraining does not improve model performance on a benchmark of behavioral tasks motivated by cognitive psychology. Kim et al. (2024) show that code pretraining improves models’ entity-tracking capabilities.
#
# Several experimental studies on the impact of code pretraining have also been conducted. Ma et al. (2024) attempt to verify the impact of code experimentally, comparing the 2.6 B parameter CodePanGu2.6 model.

# %% [markdown]
# ## Run Llama Parse on All Authors top 50 papers in last 5 years

# %%
MAX_PARSE = 1
for r in range(50):
    for author in [
        "Tal Linzen",
        "Pavel Izmailov",
        "Lerrel Pinto",
        "Kyunghyun Cho",
        "Mengye Ren",
        "Rajesh Ranganath",
        "Eunsol Choi",
        "He He",
    ]:
        load_author_select_recent_llama_parse(author, num_years=5, max_parse=MAX_PARSE)
# Out:
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id a3f5fa8b-1324-41a2-8d03-27dc21c1e5db
#  - 5 blocks for paper: [Call for Papers] The 2nd BabyLM Challenge: Sample-efficient pretraining
#   on a developmentally plausible corpus
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id df7273e5-0537-4f37-90ac-d2d2f82af66f
# .. - 49 blocks for paper: Weak-to-Strong Generalization: Eliciting Strong Capabilities With Weak
#   Supervision
# >> Reached parse: 1, break
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 277ff21e-2285-427e-af4a-5ac51a2e9ada
# .. - 23 blocks for paper: DynaMo: In-Domain Dynamics Pretraining for Visuo-Motor Control
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 6f01a3f3-eec2-45b7-95cf-adc379d855ab
# .. - 22 blocks for paper: On the design space between molecular mechanics and machine learning
#   force fields
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 7f921e4a-c776-455b-9f48-8c7e1913fcef
# ..... - 21 blocks for paper: ProCreate, Don't Reproduce! Propulsive Energy Diffusion for Creative
#   Generation
# >> Reached parse: 1, break
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id a641bfd8-2c50-4968-8702-5b64fd4714a9
# .. - 24 blocks for paper: Towards Minimal Targeted Updates of Language Models with Targeted
#   Negative Training
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 55b52a45-543c-449d-8a68-59f72044cb99
# .. - 33 blocks for paper: Long-Form Answers to Visual Questions from Blind and Low Vision People
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 6efaf993-3d73-45ca-9fa3-05f4ff8694d4
# . - 25 blocks for paper: Spontaneous Reward Hacking in Iterative Self-Refinement
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id c688cd6b-1110-46a2-8fcc-e7ff3f61844f
# . - 14 blocks for paper: SPAWNing Structural Priming Predictions from a Cognitively Motivated
#   Parser
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 8e34d178-fa58-4359-b189-29080bc30515
# .. - 20 blocks for paper: Simple and Fast Group Robustness by Automatic Feature Reweighting
# >> Reached parse: 1, break
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id d0ba6a4a-edb6-486d-9c70-cfdd3083aaa7
# ..... - 9 blocks for paper: AnySkin: Plug-and-play Skin Sensing for Robotic Touch
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 52f65628-00cc-4e9b-961b-8773441b8cbe
# .. - 23 blocks for paper: Targeted Cause Discovery with Data-Driven Learning
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 4dd1ca1c-cd55-4466-af45-73aaa5e40a71
# .. - 27 blocks for paper: Integrating Present and Past in Unsupervised Continual Learning
# >> Reached parse: 1, break
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 4258113f-b4e8-434b-81ee-a8fce1a9b0ba
# .. - 15 blocks for paper: Adaptive Sampling of k-Space in Magnetic Resonance for Rapid Pathology
#   Prediction
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id dccecd74-735f-46e8-9c76-7760e54e1fbe
# . - 35 blocks for paper: CodeUpdateArena: Benchmarking Knowledge Editing on API Updates
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 1e9206e9-f77c-4438-a9db-e4e3e8b8ef21
# . - 17 blocks for paper: LLMs Are Prone to Fallacies in Causal Inference
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 2371c303-38bf-4353-9719-d0df36c9518b
# . - 22 blocks for paper: Can You Learn Semantics Through Next-Word Prediction? The Case of
#   Entailment
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id b09d6f1f-24da-41d3-87d7-85e7e5d8a43b
# ..... - 29 blocks for paper: FlexiViT: One Model for All Patch Sizes
# >> Reached parse: 1, break
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 22be675d-8a0a-4ee3-b906-2a5f0de2baf9
# .. - 28 blocks for paper: Robot Utility Models: General Policies for Zero-Shot Deployment in New
#   Environments
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 8652e13b-2325-4163-8643-4e002aafc48e
# .Error while parsing the file '/Users/daniellerothermel/drotherm/data/raw_pdfs/2408.13430v1.pdf':
#  - 0 blocks for paper: Analysis of the ICML 2023 Ranking Data: Can Authors' Opinions of Their
#   Own Papers Assist Peer Review in Machine Learning?
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id d4117b97-4ac2-4de7-bbee-8385d997a3a2
# . - 19 blocks for paper: CoLLEGe: Concept Embedding Generation for Large Language Models
# >> Reached parse: 1, break
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id bf6c41ca-177e-49a1-903f-a9cd10b914f9
# .. - 34 blocks for paper: Preference Learning Algorithms Do Not Learn Preference Rankings
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 68e9114d-9dd0-4418-b7a0-bd4fcd4de08f
# .... - 39 blocks for paper: CaLMQA: Exploring culturally specific long-form question answering
#   across 23 languages
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 4d116355-8000-4755-828e-e0482e5e3749
# .. - 13 blocks for paper: Iterative Reasoning Preference Optimization
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 3db4b1f8-9f9c-49ca-89e3-5fb648508917
# . - 19 blocks for paper: In-context Learning Generalizes, But Not Always Robustly: The Case of
#   Syntax
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id eb69bb5f-95a4-46a0-8257-3ffeb356ca51
# . - 28 blocks for paper: On Feature Learning in the Presence of Spurious Correlations
# >> Reached parse: 1, break
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 6e4a0099-9da2-4381-90b5-7f8a27fc9fc9
# .. - 26 blocks for paper: BAKU: An Efficient Transformer for Multi-Task Policy Learning
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 6ba5cc7e-4508-4e61-b449-7f373645d830
# ... - 19 blocks for paper: Non-convolutional Graph Neural Networks
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 7bc5b3cb-cd1a-4145-bd83-0b45a4f0a96f
# . - 19 blocks for paper: Reawakening knowledge: Anticipatory recovery from catastrophic
#   interference via structured training
# >> Reached parse: 1, break
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 120b8fb3-2bc0-4244-82e4-135c8000d195
# . - 28 blocks for paper: On the Challenges and Opportunities in Generative AI
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 0b521570-86e4-41c0-be55-eb1ad387269c
# .. - 26 blocks for paper: From Distributional to Overton Pluralism: Investigating Large Language
#   Model Alignment
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id a086a034-8fe4-4edc-a8f2-f7c4c38856c7
# ....... - 112 blocks for paper: The PRISM Alignment Project: What Participatory, Representative and
#   Individualised Human Feedback Reveals About the Subjective and Multicultural
#   Alignment of Large Language Models
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id b1aada10-791c-4dca-9ab5-25801ca2c23f
# . - 20 blocks for paper: A Systematic Comparison of Syllogistic Reasoning in Humans and Language
#   Models
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 7f2e1ecf-f356-4eec-a699-695d8a9078f3
# .. - 39 blocks for paper: Last Layer Re-Training is Sufficient for Robustness to Spurious
#   Correlations
# >> Reached parse: 1, break
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id db9c8893-ab07-41e8-a03b-46a92972054b
# .... - 20 blocks for paper: OPEN TEACH: A Versatile Teleoperation System for Robotic Manipulation
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 694e47ed-355b-4b74-aba2-5bcb8b1d4737
# .................................. - 18 blocks for paper: $\mathbb{X}$-Sample Contrastive Loss: Improving Contrastive Learning
#   with Sample Similarity Graphs
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id b6448832-5d05-4360-8605-e10b867f503e
# ..... - 7 blocks for paper: Self-supervised learning of video representations from a child's
#   perspective
# >> Reached parse: 1, break
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id b19e5bdc-d412-4f83-9291-b1e26e478c5a
# . - 12 blocks for paper: Robust Anomaly Detection for Particle Physics Using Multi-Background
#   Representation Learning
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id acd3d104-baa7-4ca2-86a6-0c377dab2109
# .. - 15 blocks for paper: Exploring Design Choices for Building Language-Specific LLMs
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id c59053fd-c94d-481d-8947-7f8390aacbe1
# .. - 182 blocks for paper: Foundational Challenges in Assuring Alignment and Safety of Large
#   Language Models
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 534800f1-8893-4917-a9b7-3c074a862df3
# . - 14 blocks for paper: The Impact of Depth on Compositional Generalization in Transformer
#   Language Models
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 400260f0-87d5-4d67-8c69-205a9f18cf11
# . - 34 blocks for paper: On Uncertainty, Tempering, and Data Augmentation in Bayesian
#   Classification
# >> Reached parse: 1, break
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 17ea56ca-696f-46d9-972e-f1e658beaa10
# ... - 18 blocks for paper: Behavior Generation with Latent Actions
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 2851bc84-faaf-44d2-83df-2d109b26910f
# ... - 22 blocks for paper: Antibody DomainBed: Out-of-Distribution Generalization in Therapeutic
#   Protein Design
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 55998980-6165-40f9-b586-a772da71c15b
# . - 23 blocks for paper: Learning and Forgetting Unsafe Examples in Large Language Models
# >> Reached parse: 1, break
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id f6553417-8580-474a-95b6-8f31d67bdefa
# . - 29 blocks for paper: When accurate prediction models yield harmful self-fulfilling prophecies
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id b40c53a3-8d74-45a5-822d-cd53fb84f774
# ...... - 17 blocks for paper: SVFT: Parameter-Efficient Fine-Tuning with Singular Vectors
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 516e27d7-b8a4-49d0-a95f-e8b252c9fb66
# ... - 16 blocks for paper: Your Co-Workers Matter: Evaluating Collaborative Capabilities of
#   Language Models in Blocks World
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 298ac883-f244-40b8-bf33-2b3592855182
# ... - 16 blocks for paper: A Language Model with Limited Memory Capacity Captures Interference in
#   Human Sentence Processing
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id d028c3e9-8793-46b3-9a7f-89e15e195778
# . - 11 blocks for paper: Unsupervised learning of two-component nematicity from STM data on magic
#   angle bilayer graphene
# >> Reached parse: 1, break
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 4b37af45-6911-4c4b-9278-98038b684459
# ... - 22 blocks for paper: Hierarchical State Space Models for Continuous Sequence-to-Sequence
#   Modeling
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id efa02f9b-ccfe-42cf-9235-d8eff0bf80eb
# .. - 19 blocks for paper: MentalAgora: A Gateway to Advanced Personalized Care in Mental Health
#   through Multi-Agent Debating and Attribute Control
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 28a151fd-d956-43d9-86af-17959d4697b5
# .. - 19 blocks for paper: LifelongMemory: Leveraging LLMs for Answering Queries in Long-form
#   Egocentric Videos
# >> Reached parse: 1, break
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id dc7d4f40-51a8-443a-8601-5f5d768caee5
# ...........Error while parsing the file '/Users/daniellerothermel/drotherm/data/raw_pdfs/2311.12781v1.pdf':
#  - 0 blocks for paper: Quantifying Impairment and Disease Severity Using AI Models Trained on
#   Healthy Subjects
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 8b71ee2e-c073-4679-80a9-06eb2d513c7b
# . - 22 blocks for paper: AmbigDocs: Reasoning across Documents on Different Entities under the
#   Same Name
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 53ff861c-2e00-44f9-96bc-a44fd3c7c2cd
# . - 10 blocks for paper: Parallel Structures in Pre-training Data Yield In-Context Learning
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id ba9d1ad6-3d79-4925-8989-cc86355b082f
# . - 9 blocks for paper: Verb Conjugation in Transformers Is Determined by Linear Encodings of
#   Subject Number
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 14c63aaa-9b1b-4526-a430-7f760a155b55
# . - 59 blocks for paper: Bayesian Model Selection, the Marginal Likelihood, and Generalization
# >> Reached parse: 1, break
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 8ff8dfae-fce4-4649-89e4-d3df800108f0
# .. - 27 blocks for paper: OK-Robot: What Really Matters in Integrating Open-Knowledge Models for
#   Robotics
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 2496efe8-7a7d-4e91-a247-491a44ea91cf
# . - 13 blocks for paper: Closed-Form Test Functions for Biophysical Sequence Optimization
#   Algorithms
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id bf3d6ca7-4d86-43a7-9cc4-5bbc7e94c37f
# .. - 10 blocks for paper: BIM: Block-Wise Self-Supervised Learning with Masked Image Modeling
# >> Reached parse: 1, break
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 6fb81fd3-4709-4168-87bb-6e9c5b6691e9
# .. - 18 blocks for paper: Stochastic interpolants with data-dependent couplings
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 10bd5190-f468-4f94-a799-66d0e79963f6
# . - 21 blocks for paper: KIWI: A Dataset of Knowledge-Intensive Writing Instructions for
#   Answering Research Questions
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 40dc00ed-364e-4652-8898-15c558db777c
# . - 12 blocks for paper: Towards Consistent Natural-Language Explanations via
#   Explanation-Consistency Finetuning
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id cec16f26-d939-4427-8ec2-6f4b6de75fa7
# . - 20 blocks for paper: SLOG: A Structural Generalization Benchmark for Semantic Parsing
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 21846bed-9ed5-42f3-8bef-df5aaa51e625
# . - 35 blocks for paper: Dangers of Bayesian Model Averaging under Covariate Shift
# >> Reached parse: 1, break
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 8dcc114f-9bcf-4653-b9d0-fc7ab33a8e8a
# . - 26 blocks for paper: diff History for Neural Language Agents
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id d5072e75-5b17-42c4-8d09-42d8f1d6c05a
# . - 13 blocks for paper: Following Length Constraints in Instructions
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 702735b2-ab6e-4128-885e-1c61022b9049
# ... - 19 blocks for paper: Towards Unsupervised Object Detection From LiDAR Point Clouds
# >> Reached parse: 1, break
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 2b25a746-211c-4c1c-bf17-0b2edb651698
# ................................... - 39 blocks for paper: Don't blame Dataset Shift! Shortcut Learning due to Gradients and Cross
#   Entropy
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 3dda6d5f-1f45-4c3e-bfba-b25405cac610
# . - 16 blocks for paper: BAT: Learning to Reason about Spatial Sounds with Large Language Models
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 8c4f3b09-8bbf-47cb-a565-a7cd0a31757f
# ... - 9 blocks for paper: GOODAT: Towards Test-time Graph Out-of-Distribution Detection
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 24e27013-68f9-4c9b-bd8a-ea04abaa6487
# . - 10 blocks for paper: Do Language Models' Words Refer?
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 49c036cb-3fc1-4b91-bab9-a56dd3e052c7
# .. - 21 blocks for paper: Does Knowledge Distillation Really Work?
# >> Reached parse: 1, break
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id ee385ca0-10a9-416b-8551-5e3d9e9ca641
# ..... - 32 blocks for paper: On Bringing Robots Home
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id a47a708a-853a-45cd-8119-335b2f4b3b0f
# .............. - 28 blocks for paper: Training Greedy Policy for Proposal Batch Selection in Expensive
#   Multi-Objective Combinatorial Optimization
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 6d496da0-030e-4091-a29d-a433a6d4f92e
# .. - 30 blocks for paper: Rethinking Closed-loop Training for Autonomous Driving
# >> Reached parse: 1, break
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 62492b70-0bf9-483d-819a-7c4910892c19
# ... - 29 blocks for paper: When More is Less: Incorporating Additional Datasets Can Hurt
#   Performance By Introducing Spurious Correlations
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id e3d56350-3b0e-4462-b028-50833b6f2330
# .................... - 17 blocks for paper: Crafting In-context Examples according to LMs' Parametric Knowledge
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 00dd766f-5cbe-462b-8e74-d33c15dfae10
# . - 18 blocks for paper: Pragmatic Radiology Report Generation
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 70e96dc2-286c-4318-b45a-72bb808a1662
# . - 12 blocks for paper: Language Models Can Learn Exceptions to Syntactic Rules
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 80a8dd56-671a-4323-a266-86c164e4c00b
# .. - 24 blocks for paper: What Are Bayesian Neural Network Posteriors Really Like?
# >> Reached parse: 1, break
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id befb1152-9038-45f5-b90a-67d617ff733b
# .. - 12 blocks for paper: Open X-Embodiment: Robotic Learning Datasets and RT-X Models
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id cf4fcbc7-54f2-4109-8492-9ad42d3fb99c
# . - 27 blocks for paper: Modified Risk Formulation for Improving the Prediction of Knee
#   Osteoarthritis Progression
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 15728808-5570-495a-b76f-f96e3b8a96f3
# ................................. - 18 blocks for paper: Gaussian-Bernoulli RBMs Without Tears
# >> Reached parse: 1, break
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 87cb80f8-a641-48fb-8f78-abde4157cde0
# ...................................... - 33 blocks for paper: An Effective Meaningful Way to Evaluate Survival Models
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id e5fe43e6-4475-4161-b25f-429ab9f8fe46
# . - 16 blocks for paper: Clarify When Necessary: Resolving Ambiguity Through Interaction with LMs
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 04e1e72a-3fbb-4da0-a7e5-b71c0ed48046
# . - 18 blocks for paper: Show Your Work with Confidence: Confidence Bands for Tuning Curves
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id cd3c3652-b5cf-40a1-9c55-d563dc196699
# . - 14 blocks for paper: How to Plant Trees in Language Models: Data and Architectural Effects on
#   the Emergence of Syntactic Inductive Biases
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 9cc4dc00-01c4-4ff9-8dee-59247d70afc3
# .. - 16 blocks for paper: Learning Invariances in Neural Networks
# >> Reached parse: 1, break
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id a4d9b1d7-088e-41b4-b345-0580e8f18f02
# .. - 16 blocks for paper: PolyTask: Learning Unified Policies through Behavior Distillation
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 65b6c9eb-d59f-473b-b1fb-b3bec61e5f42
# . - 46 blocks for paper: Harmful Suicide Content Detection
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 81a92bba-cad5-4738-9559-2c21a6c6b921
# . - 31 blocks for paper: Scaling Forward Gradient With Local Losses
# >> Reached parse: 1, break
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id cda79fff-d9f8-4d16-a55a-3a2ed9cf47c0
# ... - 17 blocks for paper: A dynamic risk score for early prediction of cardiogenic shock using
#   machine learning
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 67271ec7-88c1-4e70-bca9-dc80d349e6b5
# . - 23 blocks for paper: Understanding Retrieval Augmentation for Long-Form Question Answering
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 66d06bd7-fc0c-44ef-af25-68cd3e2d8de6
# . - 17 blocks for paper: Personas as a Way to Model Truthfulness in Language Models
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id f37a5c31-d8db-4f0d-a82f-e88af374397b
# . - 22 blocks for paper: How poor is the stimulus? Evaluating hierarchical generalization in
#   neural networks trained on child-directed speech
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 23e62f68-0374-4aaf-9a6f-bbde75b87e4d
# . - 27 blocks for paper: Why Normalizing Flows Fail to Detect Out-of-Distribution Data
# >> Reached parse: 1, break
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id ad0d56ad-91ad-4226-88a6-8d43d6ac2ec1
# ... - 13 blocks for paper: See to Touch: Learning Tactile Dexterity through Visual Incentives
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id f43ffc32-335c-403d-bcb0-2527107cab6f
# . - 18 blocks for paper: Contextual Counting: A Mechanistic Study of Transformers on a
#   Quantitative Task
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 473d9e10-1320-4f02-9044-4ff8991e47f6
# . - 27 blocks for paper: Learning to Reason With Relational Abstractions
# >> Reached parse: 1, break
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 5eb0cb8f-86fb-45a8-8d8e-3bbb9e7e222a
# . - 29 blocks for paper: Don't be fooled: label leakage in explanation methods and the importance
#   of their quantitative evaluation
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 250a6791-48a9-41fa-8d6d-38045759ede9
# .. - 23 blocks for paper: RECOMP: Improving Retrieval-Augmented LMs with Compression and Selective
#   Augmentation
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 371d79c2-c18e-45dd-a920-c427c0b66ad7
# .. - 30 blocks for paper: Does Writing with Language Models Reduce Content Diversity?
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 0e9700e4-9cfc-4898-b68c-d0ec2e7757e2
# . - 14 blocks for paper: Uncontrolled Lexical Exposure Leads to Overestimation of Compositional
#   Generalization in Pretrained Models
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 1ec74d98-2a2a-40aa-8539-99cace23b8fd
# .. - 21 blocks for paper: Generalizing Convolutional Neural Networks for Equivariance to Lie
#   Groups on Arbitrary Continuous Data
# >> Reached parse: 1, break
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id c78ff389-fba6-4345-a6b5-62ce3172a8ff
# .... - 17 blocks for paper: Improving Long-Horizon Imitation Through Instruction Prediction
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 45df3d2d-8558-407d-8185-45ba8c980c45
# .... - 20 blocks for paper: Implicitly Guided Design with PropEn: Match your Data to Follow the
#   Gradient
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 734d4113-e875-452e-903e-fda8eafe4063
# .. - 32 blocks for paper: Online Unsupervised Learning of Visual Representations and Categories
# >> Reached parse: 1, break
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id a966191a-9d09-4507-9fa4-83057802cc6e
# .. - 25 blocks for paper: Beyond Distribution Shift: Spurious Features Through the Lens of
#   Training Dynamics
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id c88cc71c-f43e-4c1d-98a1-9da8f11c2f99
# .. - 28 blocks for paper: Development and Evaluation of Three Chatbots for Postpartum Mood and
#   Anxiety Disorders
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id bd30ed19-3605-4469-b51b-8d55b019978b
# .. - 8 blocks for paper: Three-dimensional angular deviation and diffraction efficiency of a
#   grating in Littrow-configuration ECDL
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id cb8a5cee-2b54-41c5-a822-c983da2e0cf7
# . - 14 blocks for paper: Causal Analysis of Syntactic Agreement Neurons in Multilingual Language
#   Models
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 36fc629e-d315-41d2-baa3-c25c2d4c6821
# . - 31 blocks for paper: Bayesian Deep Learning and a Probabilistic Perspective of Generalization
# >> Reached parse: 1, break
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 418cc763-ebc7-4823-906d-618a7c20d1b4
# ... - 8 blocks for paper: Train Offline, Test Online: A Real Robot Learning Benchmark
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 176b2e4f-c409-455a-84f2-773efaaa5476
# .............................. - 20 blocks for paper: A Framework for Multi-modal Learning: Jointly Modeling Inter- &
#   Intra-Modality Dependencies
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 690cd87c-65d7-47fc-823e-2e22d0249f6c
# . - 10 blocks for paper: Just Label What You Need: Fine-Grained Active Selection for Perception
#   and Prediction through Partially Labeled Scenes
# >> Reached parse: 1, break
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 145dba43-d094-4128-8b88-0266f310397e
# .. - 28 blocks for paper: Where to Diffuse, How to Diffuse, and How to Get Back: Automated
#   Learning for Multivariate Diffusions
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 87a15320-4c13-4ae1-ae88-522509f10f4c
# ............ - 19 blocks for paper: Propagating Knowledge Updates to LMs Through Distillation
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id be904552-4797-4400-8d02-23518ba31ba0
# .. - 11 blocks for paper: ARGUS: Visualization of AI-Assisted Task Guidance in AR
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 45651e17-ea7a-439f-bc4a-7fb1f37334a9
# .. - 20 blocks for paper: Characterizing Verbatim Short-Term Memory in Neural Language Models
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id c4e0d91e-3db9-4534-8afd-eae3d3025a0b
# . - 15 blocks for paper: Semi-Supervised Learning with Normalizing Flows
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 2ab82cd8-265e-4b49-9bdc-741116b442a6
# ... - 27 blocks for paper: NetHack is Hard to Hack
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id c4e14b60-2b68-48c6-814c-937df792df15
# ............................................. - 88 blocks for paper: A Brief Introduction to Causal Inference in Machine Learning
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id bf69ca01-f471-44e9-98ad-7316e680d63a
# .. - 12 blocks for paper: Exploring Adversarial Robustness of Multi-Sensor Perception Systems in
#   Self Driving
# >> Reached parse: 1, break
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id c9ce26a9-d21f-4958-b46c-f5abaf394e37
# . - 15 blocks for paper: Robustness to Spurious Correlations Improves Semantic
#   Out-of-Distribution Detection
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id a1937314-44b9-4815-aae1-3baf267ee9ed
# . - 10 blocks for paper: When to Use Efficient Self Attention? Profiling Text, Speech and Image
#   Transformer Variants
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id b96631ea-ece9-4ec0-9deb-0b8f0808a11a
# .. - 16 blocks for paper: Leveraging Implicit Feedback from Deployment Data in Dialogue
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 73f260e3-7c69-4eb3-b3bc-d0bd243bb7a0
# . - 12 blocks for paper: Syntactic Surprisal From Neural Models Predicts, But Underestimates,
#   Human Processing Difficulty From Syntactic Ambiguities
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 314c311b-3de7-4e07-b4c6-0b24a6e74a44
# .. - 19 blocks for paper: Dexterity from Touch: Self-Supervised Pre-Training of Tactile
#   Representations with Robotic Play
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 61f736a5-363a-42b5-967a-a87d360b6131
# . - 12 blocks for paper: MR-Transformer: Vision Transformer for Total Knee Replacement Prediction
#   Using Magnetic Resonance Imaging
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id b2470f89-c23d-45d2-9b34-594b16b21986
# ... - 17 blocks for paper: Cost-Efficient Online Hyperparameter Optimization
# >> Reached parse: 1, break
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 7aa65516-70fa-443e-b8fc-c52794a748d7
# .. - 27 blocks for paper: On the Feasibility of Machine Learning Augmented Magnetic Resonance for
#   Point-of-Care Identification of Disease
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 00a36667-c1f0-43bd-9dc5-892245fe52a4
# .. - 18 blocks for paper: Concise Answers to Complex Questions: Summarization of Long-form Answers
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id a17d4ad1-b11d-48aa-8d58-f3581a4483b3
# . - 24 blocks for paper: Do Models Explain Themselves? Counterfactual Simulatability of Natural
#   Language Explanations
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 7db335d3-a11e-4193-820a-ca0701774602
# . - 20 blocks for paper: Entailment Semantics Can Be Extracted from an Ideal Language Model
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 9911be8f-c193-4210-8274-b4cdaa4297e8
# .. - 17 blocks for paper: Teach a Robot to FISH: Versatile Imitation from One Minute of
#   Demonstrations
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 6365fec9-e393-4760-b7a0-9fcf828cd17d
# . - 11 blocks for paper: Estimation of Time-to-Total Knee Replacement Surgery
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 86b6dd69-87ab-4f05-836f-1c9cbd65a20a
# ...... - 10 blocks for paper: Adversarial Attacks On Multi-Agent Communication
# >> Reached parse: 1, break
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 3db93563-c9d9-4e01-b4fe-61c05eba82fd
# .. - 27 blocks for paper: Nuisances via Negativa: Adjusting for Spurious Correlations via Data
#   Augmentation
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id b5d04577-185e-4b41-b80d-a1492db50138
# .. - 19 blocks for paper: A Critical Evaluation of Evaluations for Long-form Question Answering
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 5364bbb5-a3e4-401e-870c-09a1b5e7319f
# . - 13 blocks for paper: Efficient Shapley Values Estimation by Amortization for Text
#   Classification
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 4fb5a794-9520-4330-ae82-5b2661f94b44
# ............ - 95 blocks for paper: Beyond the Imitation Game: Quantifying and extrapolating the
#   capabilities of language models
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 8d8a6460-f76c-4023-bc10-0445402f68c3
# . - 17 blocks for paper: From Play to Policy: Conditional Behavior Generation from Uncurated
#   Robot Data
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 5677a381-b652-4c1a-b7f4-f59811a25797
# . - 12 blocks for paper: Generalization Measures for Zero-Shot Cross-Lingual Transfer
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 10fcfc01-37b2-4a4c-b688-bba008891e3b
# .. - 13 blocks for paper: Self-Supervised Representation Learning from Flow Equivariance
# >> Reached parse: 1, break
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 6e900fbd-3865-4c16-bdf3-c76cbb8e46b9
# . - 15 blocks for paper: From algorithms to action: improving patient care requires causality
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id eccba1c8-2774-46e4-a024-4b4598e1dc0f
# . - 20 blocks for paper: Textless Low-Resource Speech-to-Speech Translation With Unit Language
#   Models
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 10fcc425-d694-4aff-9e68-4a7d11e99289
# . - 23 blocks for paper: Testing the General Deductive Reasoning Capacity of Large Language
#   Models Using OOD Examples
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 4840b3f7-07be-4c68-a587-122b2301d1ca
# . - 14 blocks for paper: When a sentence does not introduce a discourse entity, Transformer-based
#   models still sometimes refer to it
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 108efb9c-47f9-440f-819a-e3824495de4e
# .. - 10 blocks for paper: Holo-Dex: Teaching Dexterity with Immersive Mixed Reality
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id e58d0496-b036-4322-b462-f1c535d1aa53
# .. - 44 blocks for paper: HyperCLOVA X Technical Report
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 73afd5e5-55b9-42bd-bfd4-fa3822c2dab4
# ... - 17 blocks for paper: AdvSim: Generating Safety-Critical Scenarios for Self-Driving Vehicles
# >> Reached parse: 1, break
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id dfc007b3-a3c1-473e-9276-6fea1b7083bc
# . - 25 blocks for paper: Survival Mixture Density Networks
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 481e32b4-18e1-4756-9d2f-a053e9ce3d42
# . - 14 blocks for paper: Mitigating Temporal Misalignment by Discarding Outdated Facts
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id e766fb5d-29a5-4947-a916-8b31c26c2af0
# .. - 20 blocks for paper: Measuring Inductive Biases of In-Context Learning with Underspecified
#   Demonstrations
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 03f618cb-a661-414c-a419-9bb08abce72b
# . - 17 blocks for paper: Coloring the Blank Slate: Pre-training Imparts a Hierarchical Inductive
#   Bias to Sequence-to-sequence Models
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id cfd4e8dc-bec5-438c-a26b-7cd000a5d25b
# . - 11 blocks for paper: CLIP-Fields: Weakly Supervised Semantic Fields for Robotic Memory
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id cc46219b-549b-4ee6-990b-e160d37d9926
# . - 20 blocks for paper: Hyperparameters in Continual Learning: A Reality Check
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id ea167f68-9156-4121-b572-2902be8f5276
# .... - 22 blocks for paper: SceneGen: Learning to Generate Realistic Traffic Scenes
# >> Reached parse: 1, break
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id b09619fe-a760-4a4e-bcbf-b724306a59b7
# . - 25 blocks for paper: DIET: Conditional independence testing with marginal dependence measures
#   of residual information
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id ee0f93c7-3bf0-42d2-98ac-db1c0d80680c
# . - 18 blocks for paper: Continually Improving Extractive QA via Human Feedback
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 229f61d2-847f-469d-86b1-f1ce495a8a95
# .. - 10 blocks for paper: How do decoding algorithms distribute information in dialogue responses?
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 3da2a324-f3e9-4538-9951-6fe8e44f57d0
# .. - 22 blocks for paper: Improving Compositional Generalization with Latent Structure and Data
#   Augmentation
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 370cc444-2851-4e43-8fec-9d85f531221f
# .. - 9 blocks for paper: That Sounds Right: Auditory Self-Supervision for Dynamic Robot
#   Manipulation
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 7f2cf893-0a5c-4ba5-878d-a97a85981eb2
# .. - 23 blocks for paper: Self-Rewarding Language Models
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id d8820d2f-4d5b-49cb-bea9-62430e3be647
# .. - 26 blocks for paper: Probing Few-Shot Generalization with Attributes
# >> Reached parse: 1, break
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 22e9c7c0-a455-42b7-973d-d82fbf9b2ef9
# .. - 16 blocks for paper: Set Norm and Equivariant Skip Connections: Putting the Deep in Deep Sets
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 384e9ee1-34ce-45af-9dab-4865345b4260
# .. - 19 blocks for paper: Complex Claim Verification with Evidence Retrieved in the Wild
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 5fdd830f-fa89-4751-9b19-910a18952c61
# . - 17 blocks for paper: Extrapolative Controlled Sequence Generation via Iterative Refinement
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 45423081-be35-4cb7-bc1e-59e701dc1dba
# . - 54 blocks for paper: How much do language models copy from their training data? Evaluating
# ...
# >> Begin parsing number: 0
# Started parsing the file under job_id 69c280b2-6d7a-4e11-ad7a-367e2a185976
# . - 21 blocks for paper: Reinforcement Learning with Prototypical Representations
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id d4282f8d-a8b2-4411-a5d4-aac86e26653b
# .. - 17 blocks for paper: System-Level Natural Language Feedback
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 032ee1d2-341f-49d8-b3a1-81dde6ffdb46
# .. - 9 blocks for paper: The Counterfactual $χ$-GAN
# >> Reached parse: 1, break
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 86da4604-bdda-4938-8087-b8a7751e27ef
# . - 13 blocks for paper: Simulating Bandit Learning from User Feedback for Extractive Question
#   Answering
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 746586c1-3cf2-4a0c-b615-fb4241d39cb7
# . - 8 blocks for paper: Unsupervised Extractive Summarization using Pointwise Mutual Information
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 7b8ed24d-3335-4867-9e88-2738911039da
# .......... - 19 blocks for paper: Syntactic Structure from Deep Learning
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 25ca77f9-85ec-4b73-9ace-ba870b88ee4d
# . - 15 blocks for paper: Learning Cross-Domain Correspondence for Control with Dynamics
#   Cycle-Consistency
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 08fca4d5-c22f-4091-bf18-4c9dbaf5fa63
# .. - 25 blocks for paper: On Sensitivity and Robustness of Normalization Schemes to Input
#   Distribution Shifts in Automatic MR Image Diagnosis
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id edccd6be-39b1-4181-8bf0-28ef117eee45
# . - 17 blocks for paper: Energy-Inspired Models: Learning with Sampler-Induced Distributions
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 4ae1e1f3-0883-45a2-b3c7-9f9f4cae3e7c
# ..... - 17 blocks for paper: SituatedQA: Incorporating Extra-Linguistic Contexts into QA
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id ee93b77b-719c-4e11-9933-3890184737cc
# .. - 22 blocks for paper: Text Generation by Learning from Demonstrations
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 88a80b62-7c39-412e-879f-6667c8be64c1
# . - 15 blocks for paper: Does syntax need to grow on trees? Sources of hierarchical inductive
#   bias in sequence-to-sequence networks
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 127986dc-4d33-4cb3-95c2-842645695884
# ... - 9 blocks for paper: Learning Visual Robotic Control Efficiently with Contrastive
#   Pre-training and Data Augmentation
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 5a89931c-80f7-4080-9391-83f68377954d
# .. - 20 blocks for paper: Protein Discovery with Discrete Walk-Jump Sampling
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 3a4155bb-395f-4c2e-9ddb-df30f22ae358
# .. - 13 blocks for paper: Learning with Different Amounts of Annotation: From Zero to Many Labels
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 21b8b47d-d71f-4ba2-977f-501b23a66b5e
# . - 13 blocks for paper: An Empirical Study on Robustness to Spurious Correlations using
#   Pre-trained Language Models
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id ddb1441b-047a-4012-b70a-3623540694c1
# . - 11 blocks for paper: BERTs of a feather do not generalize together: Large variability in
#   generalization across models with similar test set performance
# >> Reached parse: 1, break
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 0b50ecfd-8f2b-4878-8367-db0f6f6103e9
# .. - 11 blocks for paper: Robust Policies via Mid-Level Visual Representations: An Experimental
#   Study in Manipulation and Navigation
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id b92c1a49-1d6a-48a4-bfbf-cb936dcb7a6c
# . - 18 blocks for paper: Regularizing with Pseudo-Negatives for Continual Self-Supervised
#   Learning
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id dbc3ea3c-50b2-43c3-82b7-809328d7a3a4
# . - 17 blocks for paper: CREAK: A Dataset for Commonsense Reasoning over Entity Knowledge
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 432bf532-d014-46b5-a4cd-16c5e50c17d9
# . - 16 blocks for paper: FEQA: A Question Answering Evaluation Framework for Faithfulness
#   Assessment in Abstractive Summarization
# >> Reached parse: 1, break
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id c1bdf4c1-516b-461d-9ac0-b9dbda3a6224
# . - 17 blocks for paper: Discovering the Compositional Structure of Vector Representations with
#   Role Learning Networks
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 4d6656dc-f22f-4f91-be38-bc65c7e713c5
# ... - 15 blocks for paper: Visual Imitation Made Easy
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id c9d31d33-e8bf-4aa3-8d24-91d4a29faa65
# .............. - 21 blocks for paper: BOtied: Multi-objective Bayesian optimization with tied multivariate
#   ranks
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 182ee26a-fcb4-46d8-a784-712acd3d8a17
# . - 13 blocks for paper: Knowing More About Questions Can Help: Improving Calibration in Question
#   Answering
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id fb5c9173-1018-4227-a519-ddd7d4fd4750
# .. - 18 blocks for paper: Different Set Domain Adaptation for Brain-Computer Interfaces: A Label
#   Alignment Approach
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 002bfe66-aaa0-4654-8165-7b577febb668
# .. - 18 blocks for paper: Self-Supervised Policy Adaptation during Deployment
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 6523774c-3eb2-4cd0-a123-64d8bb434158
# . - 29 blocks for paper: Protein Design with Guided Discrete Diffusion
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 0ae524b8-bc4d-42ac-bb39-8b2dead62e9d
# .. - 20 blocks for paper: Misinfo Reaction Frames: Reasoning about Readers' Reactions to News
#   Headlines
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id ba099368-ed5d-4c60-9a45-fac30286278c
# .. - 10 blocks for paper: Swoosh! Rattle! Thump! -- Actions that Sound
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 2596d4ad-4970-4fbb-ac8a-3aa1691f7b7d
# . - 16 blocks for paper: Two Failures of Self-Consistency in the Multi-Step Reasoning of LLMs
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 198c7c6f-7b4c-4dee-a7b8-522c43b5ebb3
# . - 14 blocks for paper: Can NLI Models Verify QA Systems' Predictions?
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 74fab2fc-308c-47e6-8b12-ef61f38f0667
# . - 14 blocks for paper: Automatic Curriculum Learning through Value Disagreement
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id c54ef347-227b-437a-8d5b-d29716d5a5cd
# . - 20 blocks for paper: Towards Understanding and Improving GFlowNet Training
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id c34d5bfb-e950-47e4-b442-9637da90ddf2
# . - 8 blocks for paper: Capturing Label Distribution: A Case Study in NLI
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id f3605ec8-4755-4acf-8bbe-a63a6d4e6044
# .. - 22 blocks for paper: Reinforcement Learning with Augmented Data
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 3a61ab18-a774-421c-9293-3cbd9b9f179b
# . - 5 blocks for paper: A Comparison of Semi-Supervised Learning Techniques for Streaming ASR at
#   Scale
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 5d636fa5-7bea-46bb-a92b-f493f0104683
# . - 15 blocks for paper: Decontextualization: Making Sentences Stand-Alone
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 49eb2c39-24b4-4475-b911-121e6b224754
# .. - 7 blocks for paper: State-Only Imitation Learning for Dexterous Manipulation
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id ef4a0a89-406c-41dd-8032-d2f8fde20cbe
# .. - 32 blocks for paper: Training Language Models with Language Feedback at Scale
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 516e2506-758f-42d9-99fb-4c90843e3778
# .. - 26 blocks for paper: NeurIPS 2020 EfficientQA Competition: Systems, Analyses and Lessons
#   Learned
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 47c8b7da-a8c2-4787-b5fa-041d1856082c
# .. - 9 blocks for paper: Learning Predictive Representations for Deformable Objects Using
#   Contrastive Estimation
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id ed5e27c2-1b1c-44e2-931a-327a52620b3d
# .. - 20 blocks for paper: Improving Code Generation by Training with Natural Language Feedback
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 655b1e54-9489-4c71-8953-4b34adaf0e4f
# .. - 13 blocks for paper: Challenges in Information-Seeking QA: Unanswerable Questions and
#   Paragraph Retrieval
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id c5994440-582b-420f-8f3e-d95417d11bb7
# ............ - 18 blocks for paper: Hierarchically Decoupled Imitation for Morphological Transfer
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 563983b9-44d6-4be2-87a2-eddfc073afff
# . - 5 blocks for paper: Emulating radiation transport on cosmological scale using a denoising
#   Unet
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 17f2b270-e321-4a3d-9733-587e038344eb
# .... - 18 blocks for paper: XOR QA: Cross-lingual Open-Retrieval Question Answering
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
# >> Tal Linzen has 44 / 64 in the last 5 years
# >> Pavel Izmailov has 17 / 25 in the last 5 years
# >> Lerrel Pinto has 53 / 68 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id da6cae9d-5da2-4813-a45e-ca98b510cc2c
# .... - 14 blocks for paper: Generalized Hindsight for Reinforcement Learning
# >> Reached parse: 1, break
# >> Kyunghyun Cho has 134 / 272 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 590cba50-32d7-443d-a076-07cad1ffd8fc
# ............ - 23 blocks for paper: Unsupervised Learning of Initialization in Deep Neural Networks via
#   Maximum Mean Discrepancy
# >> Reached parse: 1, break
# >> Mengye Ren has 36 / 47 in the last 5 years
# >> Rajesh Ranganath has 40 / 70 in the last 5 years
# >> Eunsol Choi has 54 / 64 in the last 5 years
# >> Begin parsing number: 0
# Started parsing the file under job_id 5aab1e83-7f08-4f61-828e-6f6ce81893ad
# . - 14 blocks for paper: QED: A Framework and Dataset for Explanations in Question Answering
# >> Reached parse: 1, break
# >> He He has 44 / 67 in the last 5 years
